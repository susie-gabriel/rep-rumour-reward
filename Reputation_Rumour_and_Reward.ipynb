# %% [markdown]
# ## SET UP
# ***

# %%
#import relevant libraries
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import random
from random import sample
random.seed(1337)
import matplotlib.animation as animation
from matplotlib.colors import ListedColormap
from csv import writer

# %%
#we will use the manhattan distance for our main metric in the lattice, using periodic boundary conditions
def d(x,y):
    vert_diff = min((x[0]-y[0])%N, (y[0]-x[0])%N)
    horiz_diff = min((x[1]-y[1])%N, (y[1]-x[1])%N)
    return vert_diff + horiz_diff

#finds the Von Neumann neighbourhood of radius r of a given coordinate, using periodic boundary conditions
def vn_nhd(x, r):
    neighbours = []
    for j in range(-(r),r+1):
        neighbours.append([x[0] % N,(x[1]+j) % N])
    for i in range(1,r+1):
        for j in range(-(r-i),r+1-i):
            neighbours.append([(x[0]-i) % N,(x[1]+j) % N])
            neighbours.append([(x[0]+i) % N,(x[1]+j) % N])
    return(neighbours)

#returns a random distinct neighbour to the subject in their von neumann neighbourhood
def random_neighbour(x,vn_nhd_size):
    candidates = vn_nhd(x,vn_nhd_size)
    neighbour = x
    while neighbour[0] == x[0] and neighbour[1] == x[1]:
        neighbour = candidates[random.randint(0,len(candidates)-1)]
    return neighbour

#testing
N = 40
x = [0,0]
print(x)
print(d(x, [4,17]))
print(len(vn_nhd(x,8)))

# %%
#used to evaluate the expected number of people a person knows the reputation of
def expected_friends(end,theta,k):
    value = 0
    for i in range(1,end+1):
        value += 4*i/(1 + np.exp((i-theta)/k))
    return value


def prob_knows(x,y):
    return 1 / (1 + np.exp(d(x,y)/4-2))

#testing
print(expected_friends(1000,8,2))
print(d([2,0],[2,8]))
print(prob_knows([2,0],[2,17]))
print(prob_knows([0,0],[0,0]))

# %%
N = 100
prob_values = np.linspace(0,20,40)
probs = [prob_knows([2,0],[2,prob_values[i]]) for i in range(len(prob_values))]

fig, ax = plt.subplots()
plt.title("Probability x knows y")
plt.ylabel("Probability")
plt.xlabel("d(x,y)")
ax.plot(prob_values, [0 for i in range(40)], linewidth=2.0, label = "Cooperators", color = "black", linestyle = "dashed")
ax.plot(prob_values, probs, linewidth=2.0, label = "Cooperators", color = "olive")
plt.show()

# %%
#custom colour map for use in visual representations of strategies
cmap = ListedColormap(["#BC2023", "#094A25"], N=2)

# %% [markdown]
# ## Round elements

# %%
def public_goods(players,t):
    communal_pot = 0
    #calculate how much money in communal funds 
    for player in players:
        if strategy[t][player[0]][player[1]] == 1: #cooperators donate to communal pot
            communal_pot += min(payoff[t][player[0]][player[1]], donation_PG) #players can't donate more than they have
            payoff[t][player[0]][player[1]] += - min(payoff[t][player[0]][player[1]], donation_PG)
            reputation[t][player[0]][player[1]] = 1
            
        elif strategy[t][player[0]][player[1]] == 0: #defectors lose reputation
            reputation[t][player[0]][player[1]] = 0
    
    for player in players: #everyone gets the money from the communal pot split
        payoff[t][player[0]][player[1]] += communal_pot * r / len(players)
        payoff[t][player[0]][player[1]] = round(payoff[t][player[0]][player[1]],2) #round to 2dp

# %%
def indirect_reciprocity(donor,recipient,t):
    if reputation[t][recipient[0]][recipient[1]] == 1:
        payoff[t][recipient[0]][recipient[1]] += benefit_IR
        payoff[t][donor[0]][donor[1]] += cost_IR
        cum_donations[t] += 1
        reputation[t][donor[0]][donor[1]] = 1
        
def indirect_reciprocity_spatial(donor,recipient,t):
    rand_no = np.random.uniform(0,1)
    if rand_no < prob_knows(donor,recipient): #donor knows recipient's reputation
        indirect_reciprocity(donor,recipient,t)
        cum_rep_known[t] += 1   #always help a good rep and get good rep, refuse to help bad rep and rep unchanged
    
    else: #always donate if you don't know reputation
        payoff[t][recipient[0]][recipient[1]] += benefit_IR
        payoff[t][donor[0]][donor[1]] += cost_IR
        cum_donations[t] += 1
        reputation[t][donor[0]][donor[1]] = 1

# %%
#compare the payoff of a subject x with a neighbour y
#change x's strategy to the y's if the payoff is strictly higher
def update_rule(x,y,t):
    #introduce variables for readability
    x_payoff = payoff[t][x[0]][x[1]] 
    y_payoff = payoff[t][y[0]][y[1]]
    


    
    #update rule applied if y has strictly greater payoff and different strategy
    if y_payoff > x_payoff and strategy[t][x[0]][x[1]] != strategy[t][y[0]][y[1]]: 
        strategy[t][x[0]][x[1]] = strategy[t][y[0]][y[1]] #x swaps strategy to y's
        
        if strategy[t][x[0]][x[1]] == 1: #if x swapped to 1
            no_cooperators[t] += 1
            cum_dc_swaps[t] += 1
        
        elif strategy[t][x[0]][x[1]] == 0: #if x swapped to 0
            no_cooperators[t] += -1
            cum_cd_swaps[t] += 1

# %% [markdown]
# ## Public Goods Only

# %%
#PARAMETERS FOR "HOW LONG DOES IT TAKE FOR COOPERATORS TO BE MADE EXTINCT IN PG"

N = 40 #for use in the NxN lattice, total population size = N^2
n = np.power(N,2) #population size
p = 10 #each player starts with £p
benefit_IR = 0 #benefit received by recipient
cost_IR = 0 #cost to donor
donation_PG = 1.25 #amount a cooperator pays
r = 2 #cooperators give donation_PG then the total amount is multiplied by r where 1 < r < n = N^2 and divided by everyone
IR_range = 1
no_rounds = 40000
no_trials = 10
spatial = False

import time
start_time = time.time()



for trial in range(no_trials):
    #the three main properties that any individual has
    #e.g. reputation[t] = the reputation matrix after the t-th round
    #reputation[0] = the initial reputation matrix
    reputation = [[] for i in range(no_rounds+1)]  
    strategy = [[] for i in range(no_rounds+1)] 
    payoff = [[] for i in range(no_rounds+1)] 

    #metrics used for evalutation
    no_cooperators = np.zeros(no_rounds+1) 
    av_defector_payoff = np.zeros(no_rounds+1) 
    av_cooperator_payoff = np.zeros(no_rounds+1) 
    cum_donations = np.zeros(no_rounds+1)  
    cum_cd_swaps = np.zeros(no_rounds+1)  
    cum_dc_swaps = np.zeros(no_rounds+1) 
    cum_rep_known = np.zeros(no_rounds+1)

    #initial values
    reputation[0] = np.ones([N,N]) #everyone starts with a reputation of 1
    strategy[0] = np.random.randint(2, size=(N, N), ) #uniformly random distributed strategies
    payoff[0] = np.array([[p for i in range(N)] for j in range(N)], dtype=float) #everyone starts with the same amount of money
    no_cooperators[0] = np.sum(strategy[0])
    av_defector_payoff[0] = p
    av_cooperator_payoff[0] = p

    print(no_cooperators[0])
    keep_running = True
    while (keep_running): #Only keeps running if non-0 number of cooperators

        #repeat round for every time step
        for t in range(1,no_rounds+1):
            #copy across all properties for new time step
            reputation[t] = reputation[t-1].copy()
            strategy[t] = strategy[t-1].copy()
            payoff[t] = payoff[t-1].copy()
            no_cooperators[t] = no_cooperators[t-1].copy()
            cum_cd_swaps[t] = cum_cd_swaps[t-1]
            cum_dc_swaps[t] = cum_dc_swaps[t-1]
            cum_donations[t] = cum_donations[t-1]
            cum_rep_known[t] = cum_rep_known[t-1]
            
            if t % 2000 ==0:
                print(t, no_cooperators[t],"cooperators")

            #public goods 5x with the focus of each game being a member of x's 1-vn-nhd
            x = np.random.randint(N,size=[2])
            for focus in vn_nhd(x, 1):
                public_goods(vn_nhd(focus,1),t)

            #indirect reciprocity 5x with the recipient of each game being a member of x's 1-vn-nhd
            for focus in vn_nhd(x, 1):
                if spatial == True:
                    indirect_reciprocity_spatial(random_neighbour(focus,IR_range), focus, t) #focus = recipient, random player in lattice = donor
                else:
                    indirect_reciprocity(random_neighbour(focus,IR_range), focus, t)

            #x decides whether to emulate neighbour's strategy or not
            update_rule(x,random_neighbour(x,1),t)

            #work out average payoff of defector and cooperators
            for i in range(N):
                for j in range(N):
                    if strategy[t][i][j] == 1:
                        av_cooperator_payoff[t] += payoff[t][i][j]/no_cooperators[t]
                    elif strategy[t][i][j] == 0:
                        av_defector_payoff[t] += payoff[t][i][j]/(n-no_cooperators[t])
            
            if (no_cooperators[t])*(n-no_cooperators[t]) == 0:
                keep_running = False
                break
            
        with open('PG_defectors_dominate.csv', 'a') as f:
                    writer_ob = writer(f)
                    if t == n:
                        writer_ob.writerow([Inf])
                    else:
                        writer_ob.writerow([t])
                    f.close()
        
        print("\ntrial", trial, "ends at", t,"\n")


print(time.time() - start_time)

# %% [markdown]
# Note that the process for all of these sections running models is essentially the same - the code blocks are seperated out to allow for different metrics to be calculated and different files to be produced. No. trials must be set manually.

# %% [markdown]
# ## Alternating Model

# %%
#PARAMETERS FOR BASE AM
N = 40 #for use in the NxN lattice, total population size = N^2
n = np.power(N,2) #population size
p = 10 #each player starts with £p
benefit_IR = 2 #benefit received by recipient
cost_IR = 1.25 #cost to donor
donation_PG = 1.25 #amount a cooperator pays
r = 2 #cooperators give donation_PG then the total amount is multiplied by r where 1 < r < n = N^2 and divided by everyone
IR_range = 8
no_rounds = 40000
no_trials = 100
spatial = False

import time
start_time = time.time()




for trial in range(no_trials):
    #the three main properties that any individual has
    reputation = [[] for i in range(no_rounds+1)]  
    strategy = [[] for i in range(no_rounds+1)] 
    payoff = [[] for i in range(no_rounds+1)] 

    #metrics used for evalutation
    no_cooperators = np.zeros(no_rounds+1) 
    av_defector_payoff = np.zeros(no_rounds+1) 
    av_cooperator_payoff = np.zeros(no_rounds+1) 
    cum_donations = np.zeros(no_rounds+1)  
    cum_cd_swaps = np.zeros(no_rounds+1)  
    cum_dc_swaps = np.zeros(no_rounds+1) 
    cum_rep_known = np.zeros(no_rounds+1)

    #initial values
    reputation[0] = np.ones([N,N]) #everyone starts with a reputation of 1
    strategy[0] = np.random.randint(2, size=(N, N), ) #uniformly random distributed strategies
    payoff[0] = np.array([[p for i in range(N)] for j in range(N)], dtype=float) #everyone starts with the same amount of money
    no_cooperators[0] = np.sum(strategy[0])
    av_defector_payoff[0] = p
    av_cooperator_payoff[0] = p

    print(0, no_cooperators[0],"cooperators")
    #repeat round for every time step
    for t in range(1,no_rounds+1):
        #copy across all properties for new time step
        reputation[t] = reputation[t-1].copy()
        strategy[t] = strategy[t-1].copy()
        payoff[t] = payoff[t-1].copy()
        no_cooperators[t] = no_cooperators[t-1].copy()
        cum_cd_swaps[t] = cum_cd_swaps[t-1]
        cum_dc_swaps[t] = cum_dc_swaps[t-1]
        cum_donations[t] = cum_donations[t-1]
        cum_rep_known[t] = cum_rep_known[t-1]
            
        if t % 2000 ==0:
            print(t, no_cooperators[t],"cooperators")

        #public goods 5x with the focus of each game being a member of x's 1-vn-nhd
        x = np.random.randint(N,size=[2])
        for focus in vn_nhd(x, 1):
            public_goods(vn_nhd(focus,1),t)

        #indirect reciprocity 5x with the recipient of each game being a member of x's 1-vn-nhd
        for focus in vn_nhd(x, 1):
            if spatial == True:
                indirect_reciprocity_spatial(random_neighbour(focus,IR_range), focus, t) #focus = recipient, random player in lattice = donor
            else:
                indirect_reciprocity(random_neighbour(focus,IR_range), focus, t)

        #x decides whether to emulate neighbour's strategy or not
        update_rule(x,random_neighbour(x,1),t)

        #work out average payoff of defector and cooperators
        for i in range(N):
            for j in range(N):
                if strategy[t][i][j] == 1:
                    av_cooperator_payoff[t] += payoff[t][i][j]/no_cooperators[t]
                elif strategy[t][i][j] == 0:
                    av_defector_payoff[t] += payoff[t][i][j]/(n-no_cooperators[t])
            
    
    
    with open('IR_base_final_coop.csv', 'a') as f:
        writer_ob = writer(f)
        writer_ob.writerow([no_cooperators[no_rounds]])
        f.close()
        
    with open('IR_base_cooperators.csv', 'a') as f:
        writer_ob = writer(f)
        writer_ob.writerow([no_cooperators[i] for i in range(0, no_rounds + 100,100)])
        f.close()
        
    with open('IR_base_coop_payoff.csv', 'a') as f:
        writer_ob = writer(f)
        writer_ob.writerow([av_cooperator_payoff[i] for i in range(0, no_rounds + 100,100)])
        f.close()
    
    with open('IR_base_defec_payoff.csv', 'a') as f:
        writer_ob = writer(f)
        writer_ob.writerow([av_defector_payoff[i] for i in range(0, no_rounds + 100,100)])
        f.close()
    
    with open('IR_base_dc_swaps.csv', 'a') as f:
        writer_ob = writer(f)
        writer_ob.writerow([cum_dc_swaps[i] for i in range(0, no_rounds + 100,100)])
        f.close()
        
    with open('IR_base_cd_swaps.csv', 'a') as f:
        writer_ob = writer(f)
        writer_ob.writerow([cum_cd_swaps[i] for i in range(0, no_rounds + 100,100)])
        f.close()
        
    with open('IR_base_final_swaps.csv', 'a') as f:
        writer_ob = writer(f)
        writer_ob.writerow([cum_cd_swaps[no_rounds], cum_dc_swaps[no_rounds]])
        f.close()
        
    with open('IR_base_cum_don.csv', 'a') as f:
        writer_ob = writer(f)
        writer_ob.writerow([cum_donations[i] for i in range(0, no_rounds + 100,100)])
        f.close()
        
    with open('IR_base_final_don.csv', 'a') as f:
        writer_ob = writer(f)
        writer_ob.writerow([cum_donations[no_rounds]])
        f.close()
    
    with open('IR_base_cum_don.csv', 'a') as f:
        writer_ob = writer(f)
        writer_ob.writerow([cum_donations[i] for i in range(0, no_rounds + 100,100)])
        f.close()
     
    av_reputation = [1] + [no_cooperators[t-1]/n for t in range(1,no_rounds+1)]
    with open('IR_base_cum_don.csv', 'a') as f:
        writer_ob = writer(f)
        writer_ob.writerow([av_reputation[i] for i in range(0, no_rounds + 100,100)])
        f.close()

        
    print("\ntrial", trial, "finished with", no_cooperators[no_rounds],"\n")

print((time.time() - start_time)/3600, "hours")
# Out:
# 8000 108.0 cooperators
# 10000 83.0 cooperators
# 12000 66.0 cooperators
# 14000 61.0 cooperators
# 16000 61.0 cooperators
# 18000 54.0 cooperators
# 20000 46.0 cooperators
# 22000 35.0 cooperators
# 24000 29.0 cooperators
# 26000 22.0 cooperators
# 28000 20.0 cooperators
# 30000 21.0 cooperators
# 32000 22.0 cooperators
# 34000 22.0 cooperators
# 36000 15.0 cooperators
# 38000 15.0 cooperators
# 40000 15.0 cooperators
#
# trial 48 finished with 15.0
#
# 0 798.0 cooperators
# 2000 464.0 cooperators
# 4000 252.0 cooperators
# 6000 139.0 cooperators
# 8000 74.0 cooperators
# 10000 48.0 cooperators
# 12000 50.0 cooperators
# 14000 38.0 cooperators
# 16000 42.0 cooperators
# 18000 37.0 cooperators
# 20000 39.0 cooperators
# 22000 43.0 cooperators
# 24000 46.0 cooperators
# 26000 53.0 cooperators
# 28000 58.0 cooperators
# 30000 67.0 cooperators
# 32000 74.0 cooperators
# 34000 70.0 cooperators
# 36000 76.0 cooperators
# 38000 93.0 cooperators
# 40000 92.0 cooperators
#
# trial 49 finished with 92.0
#
# 0 775.0 cooperators
# 2000 408.0 cooperators
# 4000 219.0 cooperators
# 6000 125.0 cooperators
# 8000 63.0 cooperators
# 10000 45.0 cooperators
# 12000 32.0 cooperators
# 14000 31.0 cooperators
# 16000 35.0 cooperators
# 18000 32.0 cooperators
# 20000 31.0 cooperators
# 22000 26.0 cooperators
# 24000 33.0 cooperators
# 26000 42.0 cooperators
# 28000 50.0 cooperators
# 30000 60.0 cooperators
# 32000 69.0 cooperators
# 34000 75.0 cooperators
# 36000 82.0 cooperators
# 38000 91.0 cooperators
# 40000 100.0 cooperators
#
# trial 50 finished with 100.0
#
# 0 797.0 cooperators
# 2000 477.0 cooperators
# 4000 269.0 cooperators
# 6000 151.0 cooperators
# 8000 112.0 cooperators
# 10000 90.0 cooperators
# 12000 78.0 cooperators
# 14000 85.0 cooperators
# 16000 74.0 cooperators
# 18000 73.0 cooperators
# 20000 77.0 cooperators
# 22000 81.0 cooperators
# 24000 73.0 cooperators
# 26000 74.0 cooperators
# 28000 75.0 cooperators
# 30000 78.0 cooperators
# 32000 87.0 cooperators
# 34000 98.0 cooperators
# 36000 100.0 cooperators
# 38000 119.0 cooperators
# 40000 131.0 cooperators
#
# trial 51 finished with 131.0
#
# 0 786.0 cooperators
# 2000 469.0 cooperators
# 4000 248.0 cooperators
# 6000 128.0 cooperators
# 8000 67.0 cooperators
# 10000 50.0 cooperators
# 12000 43.0 cooperators
# 14000 39.0 cooperators
# 16000 38.0 cooperators
# 18000 39.0 cooperators
# 20000 45.0 cooperators
# 22000 50.0 cooperators
# 24000 62.0 cooperators
# 26000 60.0 cooperators
# 28000 57.0 cooperators
# 30000 70.0 cooperators
# 32000 83.0 cooperators
# 34000 89.0 cooperators
# 36000 99.0 cooperators
# 38000 117.0 cooperators
# 40000 130.0 cooperators
#
# trial 52 finished with 130.0
#
# 0 808.0 cooperators
# 2000 510.0 cooperators
# 4000 277.0 cooperators
# 6000 157.0 cooperators
# 8000 94.0 cooperators
# 10000 66.0 cooperators
# 12000 47.0 cooperators
# 14000 42.0 cooperators
# 16000 46.0 cooperators
# 18000 45.0 cooperators
# 20000 43.0 cooperators
# 22000 48.0 cooperators
# 24000 44.0 cooperators
# 26000 45.0 cooperators
# 28000 54.0 cooperators
# 30000 69.0 cooperators
# 32000 79.0 cooperators
# 34000 80.0 cooperators
# 36000 85.0 cooperators
# 38000 89.0 cooperators
# 40000 86.0 cooperators
#
# trial 53 finished with 86.0
#
# 0 809.0 cooperators
# 2000 493.0 cooperators
# 4000 283.0 cooperators
# 6000 172.0 cooperators
# 8000 118.0 cooperators
# 10000 105.0 cooperators
# 12000 93.0 cooperators
# 14000 82.0 cooperators
# 16000 90.0 cooperators
# 18000 83.0 cooperators
# 20000 85.0 cooperators
# 22000 84.0 cooperators
# 24000 89.0 cooperators
# 26000 110.0 cooperators
# 28000 130.0 cooperators
# 30000 158.0 cooperators
# 32000 173.0 cooperators
# 34000 173.0 cooperators
# 36000 195.0 cooperators
# 38000 238.0 cooperators
# 40000 268.0 cooperators
#
# trial 54 finished with 268.0
#
# 0 807.0 cooperators
# 2000 484.0 cooperators
# 4000 288.0 cooperators
# 6000 156.0 cooperators
# 8000 102.0 cooperators
# 10000 72.0 cooperators
# 12000 49.0 cooperators
# 14000 42.0 cooperators
# 16000 41.0 cooperators
# 18000 42.0 cooperators
# 20000 38.0 cooperators
# 22000 37.0 cooperators
# 24000 43.0 cooperators
# 26000 44.0 cooperators
# 28000 48.0 cooperators
# 30000 49.0 cooperators
# 32000 57.0 cooperators
# 34000 61.0 cooperators
# 36000 59.0 cooperators
# 38000 66.0 cooperators
# 40000 67.0 cooperators
#
# trial 55 finished with 67.0
#
# 0 780.0 cooperators
# 2000 466.0 cooperators
# 4000 234.0 cooperators
# 6000 117.0 cooperators
# 8000 72.0 cooperators
# 10000 54.0 cooperators
# 12000 50.0 cooperators
# 14000 53.0 cooperators
# 16000 51.0 cooperators
# 18000 60.0 cooperators
# 20000 60.0 cooperators
# 22000 73.0 cooperators
# 24000 85.0 cooperators
# 26000 92.0 cooperators
# 28000 95.0 cooperators
# 30000 102.0 cooperators
# 32000 114.0 cooperators
# 34000 127.0 cooperators
# 36000 146.0 cooperators
# 38000 169.0 cooperators
# 40000 181.0 cooperators
#
# trial 56 finished with 181.0
#
# 0 790.0 cooperators
# 2000 467.0 cooperators
# 4000 218.0 cooperators
# 6000 103.0 cooperators
# 8000 61.0 cooperators
# 10000 34.0 cooperators
# 12000 20.0 cooperators
# 14000 14.0 cooperators
# 16000 12.0 cooperators
# 18000 8.0 cooperators
# 20000 8.0 cooperators
# 22000 11.0 cooperators
# 24000 10.0 cooperators
# 26000 9.0 cooperators
# 28000 15.0 cooperators
# 30000 14.0 cooperators
# 32000 15.0 cooperators
# 34000 13.0 cooperators
# 36000 5.0 cooperators
# 38000 4.0 cooperators
# 40000 5.0 cooperators
#
# trial 57 finished with 5.0
#
# 0 772.0 cooperators
# 2000 445.0 cooperators
# 4000 232.0 cooperators
# 6000 135.0 cooperators
# 8000 99.0 cooperators
# 10000 79.0 cooperators
# 12000 72.0 cooperators
# 14000 67.0 cooperators
# 16000 64.0 cooperators
# 18000 72.0 cooperators
# 20000 78.0 cooperators
# 22000 84.0 cooperators
# 24000 105.0 cooperators
# 26000 115.0 cooperators
# 28000 127.0 cooperators
# 30000 144.0 cooperators
# 32000 155.0 cooperators
# 34000 159.0 cooperators
# 36000 173.0 cooperators
# 38000 189.0 cooperators
# 40000 208.0 cooperators
#
# trial 58 finished with 208.0
#
# 0 797.0 cooperators
# 2000 491.0 cooperators
# 4000 241.0 cooperators
# 6000 130.0 cooperators
# 8000 89.0 cooperators
# 10000 51.0 cooperators
# 12000 37.0 cooperators
# 14000 29.0 cooperators
# 16000 33.0 cooperators
# 18000 28.0 cooperators
# 20000 22.0 cooperators
# 22000 18.0 cooperators
# 24000 12.0 cooperators
# 26000 15.0 cooperators
# 28000 19.0 cooperators
# 30000 17.0 cooperators
# 32000 16.0 cooperators
# 34000 13.0 cooperators
# 36000 16.0 cooperators
# 38000 15.0 cooperators
# 40000 18.0 cooperators
#
# trial 59 finished with 18.0
#
# 0 830.0 cooperators
# 2000 499.0 cooperators
# 4000 245.0 cooperators
# 6000 133.0 cooperators
# 8000 72.0 cooperators
# 10000 35.0 cooperators
# 12000 16.0 cooperators
# 14000 11.0 cooperators
# 16000 8.0 cooperators
# 18000 9.0 cooperators
# 20000 6.0 cooperators
# 22000 6.0 cooperators
# 24000 4.0 cooperators
# 26000 1.0 cooperators
# 28000 1.0 cooperators
# 30000 1.0 cooperators
# 32000 0.0 cooperators
# 34000 0.0 cooperators
# 36000 0.0 cooperators
# 38000 0.0 cooperators
# 40000 0.0 cooperators
#
# trial 60 finished with 0.0
#
# 0 810.0 cooperators
# 2000 481.0 cooperators
# 4000 264.0 cooperators
# 6000 148.0 cooperators
# 8000 73.0 cooperators
# 10000 54.0 cooperators
# 12000 33.0 cooperators
# 14000 27.0 cooperators
# 16000 25.0 cooperators
# 18000 22.0 cooperators
# 20000 17.0 cooperators
# 22000 22.0 cooperators
# 24000 28.0 cooperators
# 26000 29.0 cooperators
# 28000 34.0 cooperators
# 30000 36.0 cooperators
# 32000 43.0 cooperators
# 34000 43.0 cooperators
# 36000 44.0 cooperators
# 38000 41.0 cooperators
# 40000 42.0 cooperators
#
# trial 61 finished with 42.0
#
# 0 816.0 cooperators
# 2000 497.0 cooperators
# 4000 276.0 cooperators
# 6000 157.0 cooperators
# 8000 109.0 cooperators
# 10000 90.0 cooperators
# 12000 78.0 cooperators
# 14000 62.0 cooperators
# 16000 63.0 cooperators
# 18000 62.0 cooperators
# 20000 74.0 cooperators
# 22000 77.0 cooperators
# 24000 88.0 cooperators
# 26000 97.0 cooperators
# 28000 106.0 cooperators
# 30000 112.0 cooperators
# 32000 118.0 cooperators
# 34000 125.0 cooperators
# 36000 137.0 cooperators
# 38000 144.0 cooperators
# 40000 157.0 cooperators
#
# trial 62 finished with 157.0
#
# 0 809.0 cooperators
# 2000 488.0 cooperators
# 4000 264.0 cooperators
# 6000 162.0 cooperators
# 8000 108.0 cooperators
# 10000 70.0 cooperators
# 12000 72.0 cooperators
# 14000 57.0 cooperators
# 16000 52.0 cooperators
# 18000 58.0 cooperators
# 20000 63.0 cooperators
# 22000 66.0 cooperators
# 24000 76.0 cooperators
# 26000 81.0 cooperators
# 28000 96.0 cooperators
# 30000 114.0 cooperators
# 32000 124.0 cooperators
# 34000 144.0 cooperators
# 36000 150.0 cooperators
# 38000 168.0 cooperators
# 40000 190.0 cooperators
#
# trial 63 finished with 190.0
#
# 0 830.0 cooperators
# 2000 494.0 cooperators
# 4000 271.0 cooperators
# 6000 142.0 cooperators
# 8000 98.0 cooperators
# 10000 68.0 cooperators
# 12000 48.0 cooperators
# 14000 39.0 cooperators
# 16000 38.0 cooperators
# 18000 33.0 cooperators
# 20000 35.0 cooperators
# 22000 36.0 cooperators
# 24000 46.0 cooperators
# 26000 45.0 cooperators
# 28000 50.0 cooperators
# 30000 58.0 cooperators
# 32000 65.0 cooperators
# 34000 68.0 cooperators
# 36000 64.0 cooperators
# 38000 70.0 cooperators
# 40000 88.0 cooperators
#
# trial 64 finished with 88.0
#
# 0 816.0 cooperators
# 2000 479.0 cooperators
# 4000 293.0 cooperators
# 6000 166.0 cooperators
# 8000 109.0 cooperators
# 10000 84.0 cooperators
# 12000 62.0 cooperators
# 14000 62.0 cooperators
# 16000 58.0 cooperators
# 18000 62.0 cooperators
# 20000 79.0 cooperators
# 22000 88.0 cooperators
# 24000 98.0 cooperators
# 26000 98.0 cooperators
# 28000 106.0 cooperators
# 30000 119.0 cooperators
# 32000 126.0 cooperators
# 34000 134.0 cooperators
# 36000 135.0 cooperators
# 38000 138.0 cooperators
# 40000 154.0 cooperators
#
# trial 65 finished with 154.0
#
# 0 768.0 cooperators
# 2000 455.0 cooperators
# 4000 241.0 cooperators
# 6000 130.0 cooperators
# 8000 81.0 cooperators
# 10000 54.0 cooperators
# 12000 45.0 cooperators
# 14000 45.0 cooperators
# 16000 47.0 cooperators
# 18000 46.0 cooperators
# 20000 55.0 cooperators
# 22000 58.0 cooperators
# 24000 69.0 cooperators
# 26000 67.0 cooperators
# 28000 81.0 cooperators
# 30000 94.0 cooperators
# 32000 96.0 cooperators
# 34000 107.0 cooperators
# 36000 142.0 cooperators
# 38000 146.0 cooperators
# 40000 160.0 cooperators
#
# trial 66 finished with 160.0
#
# 0 800.0 cooperators
# 2000 477.0 cooperators
# 4000 287.0 cooperators
# 6000 155.0 cooperators
# 8000 85.0 cooperators
# 10000 49.0 cooperators
# 12000 45.0 cooperators
# 14000 35.0 cooperators
# 16000 36.0 cooperators
# 18000 42.0 cooperators
# 20000 46.0 cooperators
# 22000 42.0 cooperators
# 24000 43.0 cooperators
# 26000 44.0 cooperators
# 28000 44.0 cooperators
# 30000 43.0 cooperators
# 32000 45.0 cooperators
# 34000 58.0 cooperators
# 36000 67.0 cooperators
# 38000 74.0 cooperators
# 40000 83.0 cooperators
#
# trial 67 finished with 83.0
#
# 0 765.0 cooperators
# 2000 425.0 cooperators
# 4000 217.0 cooperators
# 6000 137.0 cooperators
# 8000 87.0 cooperators
# 10000 54.0 cooperators
# 12000 49.0 cooperators
# 14000 34.0 cooperators
# 16000 28.0 cooperators
# 18000 21.0 cooperators
# 20000 14.0 cooperators
# 22000 20.0 cooperators
# 24000 26.0 cooperators
# 26000 33.0 cooperators
# 28000 27.0 cooperators
# 30000 25.0 cooperators
# 32000 28.0 cooperators
# 34000 25.0 cooperators
# 36000 25.0 cooperators
# 38000 28.0 cooperators
# 40000 35.0 cooperators
#
# trial 68 finished with 35.0
#
# 0 833.0 cooperators
# 2000 563.0 cooperators
# 4000 346.0 cooperators
# 6000 231.0 cooperators
# 8000 179.0 cooperators
# 10000 158.0 cooperators
# 12000 132.0 cooperators
# 14000 102.0 cooperators
# 16000 85.0 cooperators
# 18000 84.0 cooperators
# 20000 89.0 cooperators
# 22000 86.0 cooperators
# 24000 95.0 cooperators
# 26000 99.0 cooperators
# 28000 104.0 cooperators
# 30000 104.0 cooperators
# 32000 130.0 cooperators
# 34000 150.0 cooperators
# 36000 170.0 cooperators
# 38000 186.0 cooperators
# 40000 195.0 cooperators
#
# trial 69 finished with 195.0
#
# 0 781.0 cooperators
# 2000 474.0 cooperators
# 4000 246.0 cooperators
# 6000 132.0 cooperators
# 8000 95.0 cooperators
# 10000 73.0 cooperators
# 12000 65.0 cooperators
# 14000 51.0 cooperators
# 16000 38.0 cooperators
# 18000 30.0 cooperators
# 20000 31.0 cooperators
# 22000 32.0 cooperators
# 24000 39.0 cooperators
# 26000 42.0 cooperators
# 28000 46.0 cooperators
# 30000 52.0 cooperators
# 32000 54.0 cooperators
# 34000 51.0 cooperators
# 36000 62.0 cooperators
# 38000 63.0 cooperators
# 40000 63.0 cooperators
#
# trial 70 finished with 63.0
#
# 0 822.0 cooperators
# 2000 509.0 cooperators
# 4000 282.0 cooperators
# 6000 143.0 cooperators
# 8000 94.0 cooperators
# 10000 68.0 cooperators
# 12000 52.0 cooperators
# 14000 55.0 cooperators
# 16000 56.0 cooperators
# 18000 64.0 cooperators
# 20000 77.0 cooperators
# 22000 82.0 cooperators
# 24000 92.0 cooperators
# 26000 105.0 cooperators
# 28000 125.0 cooperators
# 30000 138.0 cooperators
# 32000 147.0 cooperators
# 34000 148.0 cooperators
# 36000 166.0 cooperators
# 38000 169.0 cooperators
# 40000 177.0 cooperators
#
# trial 71 finished with 177.0
#
# 0 820.0 cooperators
# 2000 513.0 cooperators
# 4000 282.0 cooperators
# 6000 168.0 cooperators
# 8000 103.0 cooperators
# 10000 81.0 cooperators
# 12000 64.0 cooperators
# 14000 72.0 cooperators
# 16000 76.0 cooperators
# 18000 86.0 cooperators
# 20000 90.0 cooperators
# 22000 107.0 cooperators
# 24000 120.0 cooperators
# 26000 131.0 cooperators
# 28000 153.0 cooperators
# 30000 162.0 cooperators
# 32000 168.0 cooperators
# 34000 183.0 cooperators
# 36000 198.0 cooperators
# 38000 208.0 cooperators
# 40000 222.0 cooperators
#
# trial 72 finished with 222.0
#
# 0 806.0 cooperators
# 2000 489.0 cooperators
# 4000 278.0 cooperators
# 6000 138.0 cooperators
# 8000 89.0 cooperators
# 10000 55.0 cooperators
# 12000 33.0 cooperators
# 14000 24.0 cooperators
# 16000 20.0 cooperators
# 18000 20.0 cooperators
# 20000 22.0 cooperators
# 22000 21.0 cooperators
# 24000 17.0 cooperators
# 26000 12.0 cooperators
# 28000 8.0 cooperators
# 30000 11.0 cooperators
# 32000 11.0 cooperators
# 34000 15.0 cooperators
# 36000 16.0 cooperators
# 38000 13.0 cooperators
# 40000 13.0 cooperators
#
# trial 73 finished with 13.0
#
# 0 804.0 cooperators
# 2000 521.0 cooperators
# 4000 298.0 cooperators
# 6000 191.0 cooperators
# 8000 129.0 cooperators
# 10000 93.0 cooperators
# 12000 81.0 cooperators
# 14000 67.0 cooperators
# 16000 73.0 cooperators
# 18000 71.0 cooperators
# 20000 74.0 cooperators
# 22000 73.0 cooperators
# 24000 75.0 cooperators
# 26000 93.0 cooperators
# 28000 116.0 cooperators
# 30000 125.0 cooperators
# 32000 139.0 cooperators
# 34000 155.0 cooperators
# 36000 174.0 cooperators
# 38000 194.0 cooperators
# 40000 205.0 cooperators
#
# trial 74 finished with 205.0
#
# 0 794.0 cooperators
# 2000 459.0 cooperators
# 4000 272.0 cooperators
# 6000 178.0 cooperators
# 8000 114.0 cooperators
# 10000 87.0 cooperators
# 12000 82.0 cooperators
# 14000 83.0 cooperators
# 16000 78.0 cooperators
# 18000 91.0 cooperators
# 20000 91.0 cooperators
# 22000 96.0 cooperators
# 24000 112.0 cooperators
# 26000 125.0 cooperators
# 28000 143.0 cooperators
# 30000 145.0 cooperators
# 32000 167.0 cooperators
# 34000 181.0 cooperators
# 36000 202.0 cooperators
# 38000 219.0 cooperators
# 40000 240.0 cooperators
#
# trial 75 finished with 240.0
#
# 0 791.0 cooperators
# 2000 472.0 cooperators
# 4000 246.0 cooperators
# 6000 130.0 cooperators
# 8000 85.0 cooperators
# 10000 50.0 cooperators
# 12000 28.0 cooperators
# 14000 27.0 cooperators
# 16000 21.0 cooperators
# 18000 27.0 cooperators
# 20000 30.0 cooperators
# 22000 35.0 cooperators
# 24000 37.0 cooperators
# 26000 46.0 cooperators
# 28000 60.0 cooperators
# 30000 65.0 cooperators
# 32000 72.0 cooperators
# 34000 76.0 cooperators
# 36000 78.0 cooperators
# 38000 94.0 cooperators
# 40000 111.0 cooperators
#
# trial 76 finished with 111.0
#
# 0 788.0 cooperators
# 2000 437.0 cooperators
# 4000 229.0 cooperators
# 6000 137.0 cooperators
# 8000 75.0 cooperators
# 10000 50.0 cooperators
# 12000 26.0 cooperators
# 14000 15.0 cooperators
# 16000 8.0 cooperators
# 18000 3.0 cooperators
# 20000 3.0 cooperators
# 22000 0.0 cooperators
# 24000 0.0 cooperators
# 26000 0.0 cooperators
# 28000 0.0 cooperators
# 30000 0.0 cooperators
# 32000 0.0 cooperators
# 34000 0.0 cooperators
# 36000 0.0 cooperators
# 38000 0.0 cooperators
# 40000 0.0 cooperators
#
# trial 77 finished with 0.0
#
# 0 852.0 cooperators
# 2000 543.0 cooperators
# 4000 321.0 cooperators
# 6000 178.0 cooperators
# 8000 123.0 cooperators
# 10000 90.0 cooperators
# 12000 67.0 cooperators
# 14000 63.0 cooperators
# 16000 57.0 cooperators
# 18000 64.0 cooperators
# 20000 61.0 cooperators
# 22000 76.0 cooperators
# 24000 104.0 cooperators
# 26000 111.0 cooperators
# 28000 123.0 cooperators
# 30000 136.0 cooperators
# 32000 150.0 cooperators
# 34000 169.0 cooperators
# 36000 184.0 cooperators
# 38000 188.0 cooperators
# 40000 197.0 cooperators
#
# trial 78 finished with 197.0
#
# 0 834.0 cooperators
# 2000 531.0 cooperators
# 4000 310.0 cooperators
# 6000 196.0 cooperators
# 8000 117.0 cooperators
# 10000 102.0 cooperators
# 12000 78.0 cooperators
# 14000 71.0 cooperators
# 16000 75.0 cooperators
# 18000 86.0 cooperators
# 20000 89.0 cooperators
# 22000 99.0 cooperators
# 24000 106.0 cooperators
# 26000 115.0 cooperators
# 28000 128.0 cooperators
# 30000 135.0 cooperators
# 32000 141.0 cooperators
# 34000 147.0 cooperators
# 36000 166.0 cooperators
# 38000 169.0 cooperators
# 40000 181.0 cooperators
#
# trial 79 finished with 181.0
#
# 0 826.0 cooperators
# 2000 524.0 cooperators
# 4000 307.0 cooperators
# 6000 191.0 cooperators
# 8000 113.0 cooperators
# 10000 77.0 cooperators
# 12000 49.0 cooperators
# 14000 42.0 cooperators
# 16000 34.0 cooperators
# 18000 35.0 cooperators
# 20000 30.0 cooperators
# 22000 37.0 cooperators
# 24000 36.0 cooperators
# 26000 32.0 cooperators
# 28000 33.0 cooperators
# 30000 37.0 cooperators
# 32000 37.0 cooperators
# 34000 37.0 cooperators
# 36000 37.0 cooperators
# 38000 36.0 cooperators
# 40000 43.0 cooperators
#
# trial 80 finished with 43.0
#
# 0 804.0 cooperators
# 2000 484.0 cooperators
# 4000 274.0 cooperators
# 6000 146.0 cooperators
# 8000 80.0 cooperators
# 10000 52.0 cooperators
# 12000 44.0 cooperators
# 14000 31.0 cooperators
# 16000 29.0 cooperators
# 18000 24.0 cooperators
# 20000 19.0 cooperators
# 22000 20.0 cooperators
# 24000 15.0 cooperators
# 26000 19.0 cooperators
# 28000 18.0 cooperators
# 30000 12.0 cooperators
# 32000 10.0 cooperators
# 34000 6.0 cooperators
# 36000 4.0 cooperators
# 38000 1.0 cooperators
# 40000 0.0 cooperators
#
# trial 81 finished with 0.0
#
# 0 786.0 cooperators
# 2000 477.0 cooperators
# 4000 265.0 cooperators
# 6000 150.0 cooperators
# 8000 109.0 cooperators
# 10000 85.0 cooperators
# 12000 63.0 cooperators
# 14000 49.0 cooperators
# 16000 48.0 cooperators
# 18000 47.0 cooperators
# 20000 54.0 cooperators
# 22000 59.0 cooperators
# 24000 61.0 cooperators
# 26000 78.0 cooperators
# 28000 93.0 cooperators
# 30000 103.0 cooperators
# 32000 106.0 cooperators
# 34000 115.0 cooperators
# 36000 124.0 cooperators
# 38000 137.0 cooperators
# 40000 147.0 cooperators
#
# trial 82 finished with 147.0
#
# 0 807.0 cooperators
# 2000 492.0 cooperators
# 4000 288.0 cooperators
# 6000 168.0 cooperators
# 8000 116.0 cooperators
# 10000 96.0 cooperators
# 12000 65.0 cooperators
# 14000 61.0 cooperators
# 16000 40.0 cooperators
# 18000 38.0 cooperators
# 20000 34.0 cooperators
# 22000 27.0 cooperators
# 24000 28.0 cooperators
# 26000 21.0 cooperators
# 28000 27.0 cooperators
# 30000 22.0 cooperators
# 32000 17.0 cooperators
# 34000 25.0 cooperators
# 36000 30.0 cooperators
# 38000 37.0 cooperators
# 40000 36.0 cooperators
#
# trial 83 finished with 36.0
#
# 0 799.0 cooperators
# 2000 457.0 cooperators
# 4000 281.0 cooperators
# 6000 181.0 cooperators
# 8000 146.0 cooperators
# 10000 128.0 cooperators
# 12000 125.0 cooperators
# 14000 117.0 cooperators
# 16000 124.0 cooperators
# 18000 121.0 cooperators
# 20000 120.0 cooperators
# 22000 129.0 cooperators
# 24000 133.0 cooperators
# 26000 135.0 cooperators
# 28000 143.0 cooperators
# 30000 154.0 cooperators
# 32000 177.0 cooperators
# 34000 203.0 cooperators
# 36000 220.0 cooperators
# 38000 238.0 cooperators
# 40000 248.0 cooperators
#
# trial 84 finished with 248.0
#
# 0 801.0 cooperators
# 2000 481.0 cooperators
# 4000 287.0 cooperators
# 6000 174.0 cooperators
# 8000 123.0 cooperators
# 10000 94.0 cooperators
# 12000 88.0 cooperators
# 14000 85.0 cooperators
# 16000 89.0 cooperators
# 18000 89.0 cooperators
# 20000 85.0 cooperators
# 22000 86.0 cooperators
# 24000 78.0 cooperators
# 26000 95.0 cooperators
# 28000 103.0 cooperators
# 30000 109.0 cooperators
# 32000 109.0 cooperators
# 34000 123.0 cooperators
# 36000 144.0 cooperators
# 38000 160.0 cooperators
# 40000 178.0 cooperators
#
# trial 85 finished with 178.0
#
# 0 808.0 cooperators
# 2000 469.0 cooperators
# 4000 267.0 cooperators
# 6000 127.0 cooperators
# 8000 75.0 cooperators
# 10000 47.0 cooperators
# 12000 41.0 cooperators
# 14000 30.0 cooperators
# 16000 26.0 cooperators
# 18000 16.0 cooperators
# 20000 18.0 cooperators
# 22000 13.0 cooperators
# 24000 10.0 cooperators
# 26000 8.0 cooperators
# 28000 5.0 cooperators
# 30000 5.0 cooperators
# 32000 5.0 cooperators
# 34000 8.0 cooperators
# 36000 8.0 cooperators
# 38000 7.0 cooperators
# 40000 8.0 cooperators
#
# trial 86 finished with 8.0
#
# 0 803.0 cooperators
# 2000 482.0 cooperators
# 4000 278.0 cooperators
# 6000 152.0 cooperators
# 8000 79.0 cooperators
# 10000 48.0 cooperators
# 12000 37.0 cooperators
# 14000 30.0 cooperators
# 16000 26.0 cooperators
# 18000 23.0 cooperators
# 20000 20.0 cooperators
# 22000 23.0 cooperators
# 24000 25.0 cooperators
# 26000 34.0 cooperators
# 28000 36.0 cooperators
# 30000 39.0 cooperators
# 32000 43.0 cooperators
# 34000 51.0 cooperators
# 36000 63.0 cooperators
# 38000 74.0 cooperators
# 40000 71.0 cooperators
#
# trial 87 finished with 71.0
#
# 0 808.0 cooperators
# 2000 493.0 cooperators
# 4000 295.0 cooperators
# 6000 189.0 cooperators
# 8000 136.0 cooperators
# 10000 102.0 cooperators
# 12000 84.0 cooperators
# 14000 75.0 cooperators
# 16000 76.0 cooperators
# 18000 80.0 cooperators
# 20000 79.0 cooperators
# 22000 78.0 cooperators
# 24000 76.0 cooperators
# 26000 85.0 cooperators
# 28000 91.0 cooperators
# 30000 112.0 cooperators
# 32000 124.0 cooperators
# 34000 128.0 cooperators
# 36000 135.0 cooperators
# 38000 143.0 cooperators
# 40000 165.0 cooperators
#
# trial 88 finished with 165.0
#
# 0 807.0 cooperators
# 2000 488.0 cooperators
# 4000 275.0 cooperators
# 6000 175.0 cooperators
# 8000 109.0 cooperators
# 10000 75.0 cooperators
# 12000 56.0 cooperators
# 14000 45.0 cooperators
# 16000 42.0 cooperators
# 18000 49.0 cooperators
# 20000 45.0 cooperators
# 22000 47.0 cooperators
# 24000 50.0 cooperators
# 26000 56.0 cooperators
# 28000 69.0 cooperators
# 30000 67.0 cooperators
# 32000 73.0 cooperators
# 34000 75.0 cooperators
# 36000 92.0 cooperators
# 38000 94.0 cooperators
# 40000 109.0 cooperators
#
# trial 89 finished with 109.0
#
# 0 789.0 cooperators
# 2000 446.0 cooperators
# 4000 233.0 cooperators
# 6000 114.0 cooperators
# 8000 80.0 cooperators
# 10000 72.0 cooperators
# 12000 50.0 cooperators
# 14000 46.0 cooperators
# 16000 48.0 cooperators
# 18000 54.0 cooperators
# 20000 59.0 cooperators
# 22000 72.0 cooperators
# 24000 73.0 cooperators
# 26000 84.0 cooperators
# 28000 97.0 cooperators
# 30000 104.0 cooperators
# 32000 114.0 cooperators
# 34000 121.0 cooperators
# 36000 131.0 cooperators
# 38000 128.0 cooperators
# 40000 134.0 cooperators
#
# trial 90 finished with 134.0
#
# 0 809.0 cooperators
# 2000 498.0 cooperators
# 4000 250.0 cooperators
# 6000 141.0 cooperators
# 8000 87.0 cooperators
# 10000 45.0 cooperators
# 12000 24.0 cooperators
# 14000 13.0 cooperators
# 16000 8.0 cooperators
# 18000 3.0 cooperators
# 20000 1.0 cooperators
# 22000 1.0 cooperators
# 24000 0.0 cooperators
# 26000 0.0 cooperators
# 28000 0.0 cooperators
# 30000 0.0 cooperators
# 32000 0.0 cooperators
# 34000 0.0 cooperators
# 36000 0.0 cooperators
# 38000 0.0 cooperators
# 40000 0.0 cooperators
#
# trial 91 finished with 0.0
#
# 0 797.0 cooperators
# 2000 475.0 cooperators
# 4000 252.0 cooperators
# 6000 132.0 cooperators
# 8000 76.0 cooperators
# 10000 45.0 cooperators
# 12000 41.0 cooperators
# 14000 41.0 cooperators
# 16000 37.0 cooperators
# 18000 34.0 cooperators
# 20000 31.0 cooperators
# 22000 33.0 cooperators
# 24000 38.0 cooperators
# 26000 40.0 cooperators
# 28000 41.0 cooperators
# 30000 51.0 cooperators
# 32000 54.0 cooperators
# 34000 52.0 cooperators
# 36000 61.0 cooperators
# 38000 66.0 cooperators
# 40000 83.0 cooperators
#
# trial 92 finished with 83.0
#
# 0 807.0 cooperators
# 2000 477.0 cooperators
# 4000 249.0 cooperators
# 6000 123.0 cooperators
# 8000 61.0 cooperators
# 10000 30.0 cooperators
# 12000 15.0 cooperators
# 14000 13.0 cooperators
# 16000 13.0 cooperators
# 18000 9.0 cooperators
# 20000 6.0 cooperators
# 22000 2.0 cooperators
# 24000 1.0 cooperators
# 26000 1.0 cooperators
# 28000 0.0 cooperators
# 30000 0.0 cooperators
# 32000 0.0 cooperators
# 34000 0.0 cooperators
# 36000 0.0 cooperators
# 38000 0.0 cooperators
# 40000 0.0 cooperators
#
# trial 93 finished with 0.0
#
# 0 791.0 cooperators
# 2000 481.0 cooperators
# 4000 257.0 cooperators
# 6000 160.0 cooperators
# 8000 103.0 cooperators
# 10000 70.0 cooperators
# 12000 45.0 cooperators
# 14000 40.0 cooperators
# 16000 38.0 cooperators
# 18000 34.0 cooperators
# 20000 41.0 cooperators
# 22000 41.0 cooperators
# 24000 39.0 cooperators
# 26000 36.0 cooperators
# 28000 43.0 cooperators
# 30000 49.0 cooperators
# 32000 58.0 cooperators
# 34000 60.0 cooperators
# 36000 63.0 cooperators
# 38000 66.0 cooperators
# 40000 76.0 cooperators
#
# trial 94 finished with 76.0
#
# 0 782.0 cooperators
# 2000 435.0 cooperators
# 4000 230.0 cooperators
# 6000 135.0 cooperators
# 8000 77.0 cooperators
# 10000 56.0 cooperators
# 12000 44.0 cooperators
# 14000 31.0 cooperators
# 16000 35.0 cooperators
# 18000 27.0 cooperators
# 20000 28.0 cooperators
# 22000 31.0 cooperators
# 24000 35.0 cooperators
# 26000 32.0 cooperators
# 28000 38.0 cooperators
# 30000 43.0 cooperators
# 32000 51.0 cooperators
# 34000 54.0 cooperators
# 36000 59.0 cooperators
# 38000 59.0 cooperators
# 40000 62.0 cooperators
#
# trial 95 finished with 62.0
#
# 0 799.0 cooperators
# 2000 480.0 cooperators
# 4000 263.0 cooperators
# 6000 145.0 cooperators
# 8000 92.0 cooperators
# 10000 61.0 cooperators
# 12000 41.0 cooperators
# 14000 26.0 cooperators
# 16000 19.0 cooperators
# 18000 16.0 cooperators
# 20000 16.0 cooperators
# 22000 12.0 cooperators
# 24000 11.0 cooperators
# 26000 8.0 cooperators
# 28000 3.0 cooperators
# 30000 0.0 cooperators
# 32000 0.0 cooperators
# 34000 0.0 cooperators
# 36000 0.0 cooperators
# 38000 0.0 cooperators
# 40000 0.0 cooperators
#
# trial 96 finished with 0.0
#
# 0 797.0 cooperators
# 2000 475.0 cooperators
# 4000 272.0 cooperators
# 6000 165.0 cooperators
# 8000 101.0 cooperators
# 10000 65.0 cooperators
# 12000 50.0 cooperators
# 14000 41.0 cooperators
# 16000 29.0 cooperators
# 18000 31.0 cooperators
# 20000 32.0 cooperators
# 22000 41.0 cooperators
# 24000 45.0 cooperators
# 26000 45.0 cooperators
# 28000 45.0 cooperators
# 30000 49.0 cooperators
# 32000 56.0 cooperators
# 34000 49.0 cooperators
# 36000 59.0 cooperators
# 38000 76.0 cooperators
# 40000 83.0 cooperators
#
# trial 97 finished with 83.0
#
# 0 832.0 cooperators
# 2000 515.0 cooperators
# 4000 309.0 cooperators
# 6000 203.0 cooperators
# 8000 146.0 cooperators
# 10000 110.0 cooperators
# 12000 84.0 cooperators
# 14000 79.0 cooperators
# 16000 75.0 cooperators
# 18000 75.0 cooperators
# 20000 73.0 cooperators
# 22000 86.0 cooperators
# 24000 97.0 cooperators
# 26000 100.0 cooperators
# 28000 96.0 cooperators
# 30000 104.0 cooperators
# 32000 104.0 cooperators
# 34000 108.0 cooperators
# 36000 120.0 cooperators
# 38000 115.0 cooperators
# 40000 120.0 cooperators
#
# trial 98 finished with 120.0
#
# 0 760.0 cooperators
# 2000 456.0 cooperators
# 4000 231.0 cooperators
# 6000 134.0 cooperators
# 8000 75.0 cooperators
# 10000 71.0 cooperators
# 12000 66.0 cooperators
# 14000 61.0 cooperators
# 16000 70.0 cooperators
# 18000 70.0 cooperators
# 20000 78.0 cooperators
# 22000 82.0 cooperators
# 24000 81.0 cooperators
# 26000 97.0 cooperators
# 28000 110.0 cooperators
# 30000 122.0 cooperators
# 32000 127.0 cooperators
# 34000 138.0 cooperators
# 36000 155.0 cooperators
# 38000 166.0 cooperators
# 40000 176.0 cooperators
#
# trial 99 finished with 176.0
#
# 24.82410865743955 hours

# %%
#PARAMETERS FOR AM RANGE
N = 40 #for use in the NxN lattice, total population size = N^2
n = np.power(N,2) #population size
p = 10 #each player starts with £p
benefit_IR = 15 #benefit received by recipient #will have to manually change this
cost_IR = 1.25 #cost to donor
donation_PG = 1.25 #amount a cooperator pays
r = 2 #cooperators give donation_PG then the total amount is multiplied by r where 1 < r < n = N^2 and divided by everyone
IR_range = 8
no_rounds = 40000
no_trials = 30
spatial = False

import time
start_time = time.time()

defectors_time = []
cooperators_time = []
av_cooperators = np.zeros(int(no_rounds/100+1))
final_don = []
final_cd = []
final_dc = []


for trial in range(no_trials):
    #the three main properties that any individual has
    reputation = [[] for i in range(no_rounds+1)]  
    strategy = [[] for i in range(no_rounds+1)] 
    payoff = [[] for i in range(no_rounds+1)] 

    #metrics used for evalutation
    no_cooperators = np.zeros(no_rounds+1) 
    av_defector_payoff = np.zeros(no_rounds+1) 
    av_cooperator_payoff = np.zeros(no_rounds+1) 
    cum_donations = np.zeros(no_rounds+1)  
    cum_cd_swaps = np.zeros(no_rounds+1)  
    cum_dc_swaps = np.zeros(no_rounds+1) 
    cum_rep_known = np.zeros(no_rounds+1)

    #initial values
    reputation[0] = np.ones([N,N]) #everyone starts with a reputation of 1
    strategy[0] = np.random.randint(2, size=(N, N), ) #uniformly random distributed strategies
    payoff[0] = np.array([[p for i in range(N)] for j in range(N)], dtype=float) #everyone starts with the same amount of money
    no_cooperators[0] = np.sum(strategy[0])
    av_defector_payoff[0] = p
    av_cooperator_payoff[0] = p

    print(0, no_cooperators[0],"cooperators")
    
    
    #repeat round for every time step
    for t in range(1,no_rounds+1):
        #copy across all properties for new time step
        reputation[t] = reputation[t-1].copy()
        strategy[t] = strategy[t-1].copy()
        payoff[t] = payoff[t-1].copy()
        no_cooperators[t] = no_cooperators[t-1].copy()
        cum_cd_swaps[t] = cum_cd_swaps[t-1]
        cum_dc_swaps[t] = cum_dc_swaps[t-1]
        cum_donations[t] = cum_donations[t-1]
        cum_rep_known[t] = cum_rep_known[t-1]
            
        if t % 2000 ==0:
            print(t, no_cooperators[t],"cooperators")

        #public goods 5x with the focus of each game being a member of x's 1-vn-nhd
        x = np.random.randint(N,size=[2])
        for focus in vn_nhd(x, 1):
            public_goods(vn_nhd(focus,1),t)

        #indirect reciprocity 5x with the recipient of each game being a member of x's 1-vn-nhd
        for focus in vn_nhd(x, 1):
            if spatial == True:
                indirect_reciprocity_spatial(random_neighbour(focus,IR_range), focus, t) #focus = recipient, random player in lattice = donor
            else:
                indirect_reciprocity(random_neighbour(focus,IR_range), focus, t)

        #x decides whether to emulate neighbour's strategy or not
        update_rule(x,random_neighbour(x,1),t)
            
    
    for i in range(0, no_rounds + 100,100):
        av_cooperators[int(i/100)] += no_cooperators[i]/no_trials

    
    extinct = np.where(no_cooperators==0)[0]
    if extinct.size > 1:
        defectors_time.append(extinct[0])
        
    extinct = np.where(no_cooperators==n)[0]
    if extinct.size > 1:
        cooperators_time.append(extinct[0])
    print(cooperators_time)
        
    final_don.append(cum_donations[no_rounds])
    final_cd.append(cum_cd_swaps[no_rounds])
    final_dc.append(cum_dc_swaps[no_rounds])
    


        
    print("\ntrial", trial, "finished with", no_cooperators[no_rounds],"\n")

print(cooperators_time)
with open('IR_range_dom.csv', 'a') as f:
    writer_ob = writer(f)
    writer_ob.writerow([benefit_IR, defectors_time, cooperators_time])
    f.close()
    
with open('IR_range_cooperators.csv', 'a') as f:
    writer_ob = writer(f)
    writer_ob.writerow([benefit_IR, av_cooperators])
    f.close()
    
with open('IR_range_don.csv', 'a') as f:
    writer_ob = writer(f)
    writer_ob.writerow([benefit_IR, np.mean(final_don)])
    f.close()
        
with open('IR_range_swaps.csv', 'a') as f:
    writer_ob = writer(f)
    writer_ob.writerow([benefit_IR, np.mean(final_dc), np.mean(final_cd)])
    f.close()

print((time.time() - start_time)/3600, "hours")
# Out:
# 34000 1600.0 cooperators
# 36000 1600.0 cooperators
# 38000 1600.0 cooperators
# 40000 1600.0 cooperators
# [11217, 19705, 12588, 14354, 17008, 13923, 13491, 15416, 15676, 13946, 16310, 14267, 14049, 16057]
#
# trial 13 finished with 1600.0
#
# 0 812.0 cooperators
# 2000 1212.0 cooperators
# 4000 1419.0 cooperators
# 6000 1531.0 cooperators
# 8000 1585.0 cooperators
# 10000 1598.0 cooperators
# 12000 1600.0 cooperators
# 14000 1600.0 cooperators
# 16000 1600.0 cooperators
# 18000 1600.0 cooperators
# 20000 1600.0 cooperators
# 22000 1600.0 cooperators
# 24000 1600.0 cooperators
# 26000 1600.0 cooperators
# 28000 1600.0 cooperators
# 30000 1600.0 cooperators
# 32000 1600.0 cooperators
# 34000 1600.0 cooperators
# 36000 1600.0 cooperators
# 38000 1600.0 cooperators
# 40000 1600.0 cooperators
# [11217, 19705, 12588, 14354, 17008, 13923, 13491, 15416, 15676, 13946, 16310, 14267, 14049, 16057, 11230]
#
# trial 14 finished with 1600.0
#
# 0 818.0 cooperators
# 2000 1237.0 cooperators
# 4000 1454.0 cooperators
# 6000 1547.0 cooperators
# 8000 1578.0 cooperators
# 10000 1594.0 cooperators
# 12000 1597.0 cooperators
# 14000 1598.0 cooperators
# 16000 1600.0 cooperators
# 18000 1600.0 cooperators
# 20000 1600.0 cooperators
# 22000 1600.0 cooperators
# 24000 1600.0 cooperators
# 26000 1600.0 cooperators
# 28000 1600.0 cooperators
# 30000 1600.0 cooperators
# 32000 1600.0 cooperators
# 34000 1600.0 cooperators
# 36000 1600.0 cooperators
# 38000 1600.0 cooperators
# 40000 1600.0 cooperators
# [11217, 19705, 12588, 14354, 17008, 13923, 13491, 15416, 15676, 13946, 16310, 14267, 14049, 16057, 11230, 15018]
#
# trial 15 finished with 1600.0
#
# 0 829.0 cooperators
# 2000 1221.0 cooperators
# 4000 1442.0 cooperators
# 6000 1543.0 cooperators
# 8000 1589.0 cooperators
# 10000 1597.0 cooperators
# 12000 1599.0 cooperators
# 14000 1600.0 cooperators
# 16000 1600.0 cooperators
# 18000 1600.0 cooperators
# 20000 1600.0 cooperators
# 22000 1600.0 cooperators
# 24000 1600.0 cooperators
# 26000 1600.0 cooperators
# 28000 1600.0 cooperators
# 30000 1600.0 cooperators
# 32000 1600.0 cooperators
# 34000 1600.0 cooperators
# 36000 1600.0 cooperators
# 38000 1600.0 cooperators
# 40000 1600.0 cooperators
# [11217, 19705, 12588, 14354, 17008, 13923, 13491, 15416, 15676, 13946, 16310, 14267, 14049, 16057, 11230, 15018, 12360]
#
# trial 16 finished with 1600.0
#
# 0 780.0 cooperators
# 2000 1179.0 cooperators
# 4000 1424.0 cooperators
# 6000 1539.0 cooperators
# 8000 1575.0 cooperators
# 10000 1589.0 cooperators
# 12000 1598.0 cooperators
# 14000 1600.0 cooperators
# 16000 1600.0 cooperators
# 18000 1600.0 cooperators
# 20000 1600.0 cooperators
# 22000 1600.0 cooperators
# 24000 1600.0 cooperators
# 26000 1600.0 cooperators
# 28000 1600.0 cooperators
# 30000 1600.0 cooperators
# 32000 1600.0 cooperators
# 34000 1600.0 cooperators
# 36000 1600.0 cooperators
# 38000 1600.0 cooperators
# 40000 1600.0 cooperators
# [11217, 19705, 12588, 14354, 17008, 13923, 13491, 15416, 15676, 13946, 16310, 14267, 14049, 16057, 11230, 15018, 12360, 12351]
#
# trial 17 finished with 1600.0
#
# 0 808.0 cooperators
# 2000 1210.0 cooperators
# 4000 1434.0 cooperators
# 6000 1546.0 cooperators
# 8000 1584.0 cooperators
# 10000 1595.0 cooperators
# 12000 1600.0 cooperators
# 14000 1600.0 cooperators
# 16000 1600.0 cooperators
# 18000 1600.0 cooperators
# 20000 1600.0 cooperators
# 22000 1600.0 cooperators
# 24000 1600.0 cooperators
# 26000 1600.0 cooperators
# 28000 1600.0 cooperators
# 30000 1600.0 cooperators
# 32000 1600.0 cooperators
# 34000 1600.0 cooperators
# 36000 1600.0 cooperators
# 38000 1600.0 cooperators
# 40000 1600.0 cooperators
# [11217, 19705, 12588, 14354, 17008, 13923, 13491, 15416, 15676, 13946, 16310, 14267, 14049, 16057, 11230, 15018, 12360, 12351, 11390]
#
# trial 18 finished with 1600.0
#
# 0 810.0 cooperators
# 2000 1193.0 cooperators
# 4000 1433.0 cooperators
# 6000 1534.0 cooperators
# 8000 1579.0 cooperators
# 10000 1595.0 cooperators
# 12000 1599.0 cooperators
# 14000 1600.0 cooperators
# 16000 1600.0 cooperators
# 18000 1600.0 cooperators
# 20000 1600.0 cooperators
# 22000 1600.0 cooperators
# 24000 1600.0 cooperators
# 26000 1600.0 cooperators
# 28000 1600.0 cooperators
# 30000 1600.0 cooperators
# 32000 1600.0 cooperators
# 34000 1600.0 cooperators
# 36000 1600.0 cooperators
# 38000 1600.0 cooperators
# 40000 1600.0 cooperators
# [11217, 19705, 12588, 14354, 17008, 13923, 13491, 15416, 15676, 13946, 16310, 14267, 14049, 16057, 11230, 15018, 12360, 12351, 11390, 12423]
#
# trial 19 finished with 1600.0
#
# 0 778.0 cooperators
# 2000 1183.0 cooperators
# 4000 1415.0 cooperators
# 6000 1529.0 cooperators
# 8000 1581.0 cooperators
# 10000 1592.0 cooperators
# 12000 1596.0 cooperators
# 14000 1598.0 cooperators
# 16000 1599.0 cooperators
# 18000 1600.0 cooperators
# 20000 1600.0 cooperators
# 22000 1600.0 cooperators
# 24000 1600.0 cooperators
# 26000 1600.0 cooperators
# 28000 1600.0 cooperators
# 30000 1600.0 cooperators
# 32000 1600.0 cooperators
# 34000 1600.0 cooperators
# 36000 1600.0 cooperators
# 38000 1600.0 cooperators
# 40000 1600.0 cooperators
# [11217, 19705, 12588, 14354, 17008, 13923, 13491, 15416, 15676, 13946, 16310, 14267, 14049, 16057, 11230, 15018, 12360, 12351, 11390, 12423, 17364]
#
# trial 20 finished with 1600.0
#
# 0 795.0 cooperators
# 2000 1187.0 cooperators
# 4000 1412.0 cooperators
# 6000 1544.0 cooperators
# 8000 1583.0 cooperators
# 10000 1592.0 cooperators
# 12000 1596.0 cooperators
# 14000 1600.0 cooperators
# 16000 1600.0 cooperators
# 18000 1600.0 cooperators
# 20000 1600.0 cooperators
# 22000 1600.0 cooperators
# 24000 1600.0 cooperators
# 26000 1600.0 cooperators
# 28000 1600.0 cooperators
# 30000 1600.0 cooperators
# 32000 1600.0 cooperators
# 34000 1600.0 cooperators
# 36000 1600.0 cooperators
# 38000 1600.0 cooperators
# 40000 1600.0 cooperators
# [11217, 19705, 12588, 14354, 17008, 13923, 13491, 15416, 15676, 13946, 16310, 14267, 14049, 16057, 11230, 15018, 12360, 12351, 11390, 12423, 17364, 12484]
#
# trial 21 finished with 1600.0
#
# 0 762.0 cooperators
# 2000 1193.0 cooperators
# 4000 1434.0 cooperators
# 6000 1544.0 cooperators
# 8000 1580.0 cooperators
# 10000 1592.0 cooperators
# 12000 1595.0 cooperators
# 14000 1599.0 cooperators
# 16000 1599.0 cooperators
# 18000 1600.0 cooperators
# 20000 1600.0 cooperators
# 22000 1600.0 cooperators
# 24000 1600.0 cooperators
# 26000 1600.0 cooperators
# 28000 1600.0 cooperators
# 30000 1600.0 cooperators
# 32000 1600.0 cooperators
# 34000 1600.0 cooperators
# 36000 1600.0 cooperators
# 38000 1600.0 cooperators
# 40000 1600.0 cooperators
# [11217, 19705, 12588, 14354, 17008, 13923, 13491, 15416, 15676, 13946, 16310, 14267, 14049, 16057, 11230, 15018, 12360, 12351, 11390, 12423, 17364, 12484, 17590]
#
# trial 22 finished with 1600.0
#
# 0 826.0 cooperators
# 2000 1227.0 cooperators
# 4000 1434.0 cooperators
# 6000 1535.0 cooperators
# 8000 1580.0 cooperators
# 10000 1593.0 cooperators
# 12000 1598.0 cooperators
# 14000 1599.0 cooperators
# 16000 1599.0 cooperators
# 18000 1600.0 cooperators
# 20000 1600.0 cooperators
# 22000 1600.0 cooperators
# 24000 1600.0 cooperators
# 26000 1600.0 cooperators
# 28000 1600.0 cooperators
# 30000 1600.0 cooperators
# 32000 1600.0 cooperators
# 34000 1600.0 cooperators
# 36000 1600.0 cooperators
# 38000 1600.0 cooperators
# 40000 1600.0 cooperators
# [11217, 19705, 12588, 14354, 17008, 13923, 13491, 15416, 15676, 13946, 16310, 14267, 14049, 16057, 11230, 15018, 12360, 12351, 11390, 12423, 17364, 12484, 17590, 16329]
#
# trial 23 finished with 1600.0
#
# 0 821.0 cooperators
# 2000 1235.0 cooperators
# 4000 1436.0 cooperators
# 6000 1541.0 cooperators
# 8000 1580.0 cooperators
# 10000 1594.0 cooperators
# 12000 1598.0 cooperators
# 14000 1600.0 cooperators
# 16000 1600.0 cooperators
# 18000 1600.0 cooperators
# 20000 1600.0 cooperators
# 22000 1600.0 cooperators
# 24000 1600.0 cooperators
# 26000 1600.0 cooperators
# 28000 1600.0 cooperators
# 30000 1600.0 cooperators
# 32000 1600.0 cooperators
# 34000 1600.0 cooperators
# 36000 1600.0 cooperators
# 38000 1600.0 cooperators
# 40000 1600.0 cooperators
# [11217, 19705, 12588, 14354, 17008, 13923, 13491, 15416, 15676, 13946, 16310, 14267, 14049, 16057, 11230, 15018, 12360, 12351, 11390, 12423, 17364, 12484, 17590, 16329, 12921]
#
# trial 24 finished with 1600.0
#
# 0 773.0 cooperators
# 2000 1193.0 cooperators
# 4000 1426.0 cooperators
# 6000 1526.0 cooperators
# 8000 1571.0 cooperators
# 10000 1591.0 cooperators
# 12000 1595.0 cooperators
# 14000 1598.0 cooperators
# 16000 1599.0 cooperators
# 18000 1599.0 cooperators
# 20000 1600.0 cooperators
# 22000 1600.0 cooperators
# 24000 1600.0 cooperators
# 26000 1600.0 cooperators
# 28000 1600.0 cooperators
# 30000 1600.0 cooperators
# 32000 1600.0 cooperators
# 34000 1600.0 cooperators
# 36000 1600.0 cooperators
# 38000 1600.0 cooperators
# 40000 1600.0 cooperators
# [11217, 19705, 12588, 14354, 17008, 13923, 13491, 15416, 15676, 13946, 16310, 14267, 14049, 16057, 11230, 15018, 12360, 12351, 11390, 12423, 17364, 12484, 17590, 16329, 12921, 18671]
#
# trial 25 finished with 1600.0
#
# 0 808.0 cooperators
# 2000 1223.0 cooperators
# 4000 1461.0 cooperators
# 6000 1547.0 cooperators
# 8000 1581.0 cooperators
# 10000 1595.0 cooperators
# 12000 1598.0 cooperators
# 14000 1599.0 cooperators
# 16000 1600.0 cooperators
# 18000 1600.0 cooperators
# 20000 1600.0 cooperators
# 22000 1600.0 cooperators
# 24000 1600.0 cooperators
# 26000 1600.0 cooperators
# 28000 1600.0 cooperators
# 30000 1600.0 cooperators
# 32000 1600.0 cooperators
# 34000 1600.0 cooperators
# 36000 1600.0 cooperators
# 38000 1600.0 cooperators
# 40000 1600.0 cooperators
# [11217, 19705, 12588, 14354, 17008, 13923, 13491, 15416, 15676, 13946, 16310, 14267, 14049, 16057, 11230, 15018, 12360, 12351, 11390, 12423, 17364, 12484, 17590, 16329, 12921, 18671, 14381]
#
# trial 26 finished with 1600.0
#
# 0 807.0 cooperators
# 2000 1211.0 cooperators
# 4000 1432.0 cooperators
# 6000 1540.0 cooperators
# 8000 1579.0 cooperators
# 10000 1594.0 cooperators
# 12000 1598.0 cooperators
# 14000 1600.0 cooperators
# 16000 1600.0 cooperators
# 18000 1600.0 cooperators
# 20000 1600.0 cooperators
# 22000 1600.0 cooperators
# 24000 1600.0 cooperators
# 26000 1600.0 cooperators
# 28000 1600.0 cooperators
# 30000 1600.0 cooperators
# 32000 1600.0 cooperators
# 34000 1600.0 cooperators
# 36000 1600.0 cooperators
# 38000 1600.0 cooperators
# 40000 1600.0 cooperators
# [11217, 19705, 12588, 14354, 17008, 13923, 13491, 15416, 15676, 13946, 16310, 14267, 14049, 16057, 11230, 15018, 12360, 12351, 11390, 12423, 17364, 12484, 17590, 16329, 12921, 18671, 14381, 13558]
#
# trial 27 finished with 1600.0
#
# 0 782.0 cooperators
# 2000 1183.0 cooperators
# 4000 1432.0 cooperators
# 6000 1536.0 cooperators
# 8000 1576.0 cooperators
# 10000 1593.0 cooperators
# 12000 1598.0 cooperators
# 14000 1600.0 cooperators
# 16000 1600.0 cooperators
# 18000 1600.0 cooperators
# 20000 1600.0 cooperators
# 22000 1600.0 cooperators
# 24000 1600.0 cooperators
# 26000 1600.0 cooperators
# 28000 1600.0 cooperators
# 30000 1600.0 cooperators
# 32000 1600.0 cooperators
# 34000 1600.0 cooperators
# 36000 1600.0 cooperators
# 38000 1600.0 cooperators
# 40000 1600.0 cooperators
# [11217, 19705, 12588, 14354, 17008, 13923, 13491, 15416, 15676, 13946, 16310, 14267, 14049, 16057, 11230, 15018, 12360, 12351, 11390, 12423, 17364, 12484, 17590, 16329, 12921, 18671, 14381, 13558, 13787]
#
# trial 28 finished with 1600.0
#
# 0 788.0 cooperators
# 2000 1186.0 cooperators
# 4000 1422.0 cooperators
# 6000 1532.0 cooperators
# 8000 1574.0 cooperators
# 10000 1594.0 cooperators
# 12000 1597.0 cooperators
# 14000 1598.0 cooperators
# 16000 1600.0 cooperators
# 18000 1600.0 cooperators
# 20000 1600.0 cooperators
# 22000 1600.0 cooperators
# 24000 1600.0 cooperators
# 26000 1600.0 cooperators
# 28000 1600.0 cooperators
# 30000 1600.0 cooperators
# 32000 1600.0 cooperators
# 34000 1600.0 cooperators
# 36000 1600.0 cooperators
# 38000 1600.0 cooperators
# 40000 1600.0 cooperators
# [11217, 19705, 12588, 14354, 17008, 13923, 13491, 15416, 15676, 13946, 16310, 14267, 14049, 16057, 11230, 15018, 12360, 12351, 11390, 12423, 17364, 12484, 17590, 16329, 12921, 18671, 14381, 13558, 13787, 15598]
#
# trial 29 finished with 1600.0
#
# [11217, 19705, 12588, 14354, 17008, 13923, 13491, 15416, 15676, 13946, 16310, 14267, 14049, 16057, 11230, 15018, 12360, 12351, 11390, 12423, 17364, 12484, 17590, 16329, 12921, 18671, 14381, 13558, 13787, 15598]
# 0.5660750540759828 hours

# %% [markdown]
# ## Spatial Alternating Model

# %%
#PARAMETERS FOR SPATIAL
N = 40 #for use in the NxN lattice, total population size = N^2
n = np.power(N,2) #population size
p = 10 #each player starts with £p
benefit_IR = 2 #benefit received by recipient
cost_IR = 1.25 #cost to donor
donation_PG = 1.25 #amount a cooperator pays
r = 2 #cooperators give donation_PG then the total amount is multiplied by r and divided by everyone
IR_range = 8
no_rounds = 40000
no_trials = 63
spatial = True

import time
start_time = time.time()




for trial in range(no_trials):
    #the three main properties that any individual has
    reputation = [[] for i in range(no_rounds+1)]  
    strategy = [[] for i in range(no_rounds+1)] 
    payoff = [[] for i in range(no_rounds+1)] 

    #metrics used for evalutation
    no_cooperators = np.zeros(no_rounds+1) 
    av_defector_payoff = np.zeros(no_rounds+1) 
    av_cooperator_payoff = np.zeros(no_rounds+1) 
    cum_donations = np.zeros(no_rounds+1)  
    cum_cd_swaps = np.zeros(no_rounds+1)  
    cum_dc_swaps = np.zeros(no_rounds+1) 
    cum_rep_known = np.zeros(no_rounds+1)

    #initial values
    reputation[0] = np.ones([N,N]) #everyone starts with a reputation of 1
    strategy[0] = np.random.randint(2, size=(N, N), ) #uniformly random distributed strategies
    payoff[0] = np.array([[p for i in range(N)] for j in range(N)], dtype=float) 
    #everyone starts with the same amount of money
    no_cooperators[0] = np.sum(strategy[0])
    av_defector_payoff[0] = p
    av_cooperator_payoff[0] = p

    print(0, no_cooperators[0],"cooperators")
    #repeat round for every time step
    for t in range(1,no_rounds+1):
        #copy across all properties for new time step
        reputation[t] = reputation[t-1].copy()
        strategy[t] = strategy[t-1].copy()
        payoff[t] = payoff[t-1].copy()
        no_cooperators[t] = no_cooperators[t-1].copy()
        cum_cd_swaps[t] = cum_cd_swaps[t-1]
        cum_dc_swaps[t] = cum_dc_swaps[t-1]
        cum_donations[t] = cum_donations[t-1]
        cum_rep_known[t] = cum_rep_known[t-1]
            
        if t % 2000 ==0:
            print(t, cum_donations[t],"donations")

        #public goods 5x with the focus of each game being a member of x's 1-vn-nhd
        x = np.random.randint(N,size=[2])
        for focus in vn_nhd(x, 1):
            public_goods(vn_nhd(focus,1),t)

        #indirect reciprocity 5x with the recipient of each game being a member of x's 1-vn-nhd
        for focus in vn_nhd(x, 1):
            if spatial == True:
                indirect_reciprocity_spatial(random_neighbour(focus,IR_range), focus, t)
                #focus = recipient, random player in lattice = donor
            else:
                indirect_reciprocity(random_neighbour(focus,IR_range), focus, t)

        #x decides whether to emulate neighbour's strategy or not
        update_rule(x,random_neighbour(x,1),t)

        #work out average payoff of defector and cooperators
        for i in range(N):
            for j in range(N):
                if strategy[t][i][j] == 1:
                    av_cooperator_payoff[t] += payoff[t][i][j]/no_cooperators[t]
                elif strategy[t][i][j] == 0:
                    av_defector_payoff[t] += payoff[t][i][j]/(n-no_cooperators[t])
            

    with open('Spatial_base_final_coop.csv', 'a') as f:
        writer_ob = writer(f)
        writer_ob.writerow([no_cooperators[no_rounds]])
        f.close()
        
    with open('Spatial_base_cooperators.csv', 'a') as f:
        writer_ob = writer(f)
        writer_ob.writerow([no_cooperators[i] for i in range(0, no_rounds + 100,100)])
        f.close()
        
    with open('Spatial_base_coop_payoff.csv', 'a') as f:
        writer_ob = writer(f)
        writer_ob.writerow([av_cooperator_payoff[i] for i in range(0, no_rounds + 100,100)])
        f.close()
    
    with open('Spatial_base_defec_payoff.csv', 'a') as f:
        writer_ob = writer(f)
        writer_ob.writerow([av_defector_payoff[i] for i in range(0, no_rounds + 100,100)])
        f.close()
    
    with open('Spatial_base_dc_swaps.csv', 'a') as f:
        writer_ob = writer(f)
        writer_ob.writerow([cum_dc_swaps[i] for i in range(0, no_rounds + 100,100)])
        f.close()
        
    with open('Spatial_base_cd_swaps.csv', 'a') as f:
        writer_ob = writer(f)
        writer_ob.writerow([cum_cd_swaps[i] for i in range(0, no_rounds + 100,100)])
        f.close()
        
    with open('Spatial_base_final_swaps.csv', 'a') as f:
        writer_ob = writer(f)
        writer_ob.writerow([cum_cd_swaps[no_rounds], cum_dc_swaps[no_rounds]])
        f.close()
    
  
    with open('Spatial_base_final_don.csv', 'a') as f:
        writer_ob = writer(f)
        writer_ob.writerow([cum_donations[no_rounds]])
        f.close()
    
    with open('Spatial_base_cum_don.csv', 'a') as f:
        writer_ob = writer(f)
        writer_ob.writerow([cum_donations[i] for i in range(0, no_rounds + 100,100)])
        f.close()
     
    av_reputation = [1] + [no_cooperators[t-1]/n for t in range(1,no_rounds+1)]
    with open('Spatial_base_cum_don.csv', 'a') as f:
        writer_ob = writer(f)
        writer_ob.writerow([av_reputation[i] for i in range(0, no_rounds + 100,100)])
        f.close()
        
    with open('Spatial_base_cum_rep_known.csv', 'a') as f:
        writer_ob = writer(f)
        writer_ob.writerow([cum_rep_known[i] for i in range(0, no_rounds + 100,100)])
        f.close()

     
    print("\ntrial", trial, "finished with", no_cooperators[no_rounds],"\n")

print((time.time() - start_time)/3600, "hours")
# Out:
# 30000 48385.0 donations
# 32000 51163.0 donations
# 34000 54003.0 donations
# 36000 56835.0 donations
# 38000 59695.0 donations
# 40000 62477.0 donations
#
# trial 15 finished with 4.0
#
# 0 798.0 cooperators
# 2000 5565.0 donations
# 4000 9866.0 donations
# 6000 13586.0 donations
# 8000 16740.0 donations
# 10000 19812.0 donations
# 12000 22707.0 donations
# 14000 25572.0 donations
# 16000 28343.0 donations
# 18000 31155.0 donations
# 20000 34058.0 donations
# 22000 36856.0 donations
# 24000 39635.0 donations
# 26000 42510.0 donations
# 28000 45337.0 donations
# 30000 48181.0 donations
# 32000 50902.0 donations
# 34000 53773.0 donations
# 36000 56565.0 donations
# 38000 59289.0 donations
# 40000 62106.0 donations
#
# trial 16 finished with 0.0
#
# 0 807.0 cooperators
# 2000 5672.0 donations
# 4000 10043.0 donations
# 6000 13613.0 donations
# 8000 16927.0 donations
# 10000 19915.0 donations
# 12000 22890.0 donations
# 14000 25765.0 donations
# 16000 28694.0 donations
# 18000 31612.0 donations
# 20000 34577.0 donations
# 22000 37498.0 donations
# 24000 40452.0 donations
# 26000 43309.0 donations
# 28000 46195.0 donations
# 30000 49117.0 donations
# 32000 51931.0 donations
# 34000 54825.0 donations
# 36000 57794.0 donations
# 38000 60749.0 donations
# 40000 63648.0 donations
#
# trial 17 finished with 37.0
#
# 0 855.0 cooperators
# 2000 5832.0 donations
# 4000 10378.0 donations
# 6000 14099.0 donations
# 8000 17410.0 donations
# 10000 20513.0 donations
# 12000 23474.0 donations
# 14000 26322.0 donations
# 16000 29207.0 donations
# 18000 32108.0 donations
# 20000 34950.0 donations
# 22000 37799.0 donations
# 24000 40688.0 donations
# 26000 43577.0 donations
# 28000 46448.0 donations
# 30000 49300.0 donations
# 32000 52194.0 donations
# 34000 55061.0 donations
# 36000 57934.0 donations
# 38000 60810.0 donations
# 40000 63696.0 donations
#
# trial 18 finished with 17.0
#
# 0 853.0 cooperators
# 2000 5856.0 donations
# 4000 10471.0 donations
# 6000 14284.0 donations
# 8000 17690.0 donations
# 10000 20835.0 donations
# 12000 23931.0 donations
# 14000 27037.0 donations
# 16000 30031.0 donations
# 18000 32995.0 donations
# 20000 36065.0 donations
# 22000 39140.0 donations
# 24000 42017.0 donations
# 26000 44988.0 donations
# 28000 47951.0 donations
# 30000 50973.0 donations
# 32000 54073.0 donations
# 34000 57242.0 donations
# 36000 60378.0 donations
# 38000 63435.0 donations
# 40000 66582.0 donations
#
# trial 19 finished with 97.0
#
# 0 833.0 cooperators
# 2000 5658.0 donations
# 4000 10054.0 donations
# 6000 13693.0 donations
# 8000 16955.0 donations
# 10000 19931.0 donations
# 12000 22887.0 donations
# 14000 25840.0 donations
# 16000 28638.0 donations
# 18000 31479.0 donations
# 20000 34243.0 donations
# 22000 36981.0 donations
# 24000 39752.0 donations
# 26000 42493.0 donations
# 28000 45153.0 donations
# 30000 48021.0 donations
# 32000 50800.0 donations
# 34000 53601.0 donations
# 36000 56419.0 donations
# 38000 59177.0 donations
# 40000 61910.0 donations
#
# trial 20 finished with 0.0
#
# 0 782.0 cooperators
# 2000 5574.0 donations
# 4000 9884.0 donations
# 6000 13310.0 donations
# 8000 16464.0 donations
# 10000 19537.0 donations
# 12000 22443.0 donations
# 14000 25316.0 donations
# 16000 28222.0 donations
# 18000 31105.0 donations
# 20000 33807.0 donations
# 22000 36572.0 donations
# 24000 39437.0 donations
# 26000 42277.0 donations
# 28000 45089.0 donations
# 30000 47896.0 donations
# 32000 50657.0 donations
# 34000 53415.0 donations
# 36000 56240.0 donations
# 38000 59109.0 donations
# 40000 61917.0 donations
#
# trial 21 finished with 7.0
#
# 0 799.0 cooperators
# 2000 5568.0 donations
# 4000 9793.0 donations
# 6000 13347.0 donations
# 8000 16509.0 donations
# 10000 19448.0 donations
# 12000 22398.0 donations
# 14000 25216.0 donations
# 16000 28038.0 donations
# 18000 30948.0 donations
# 20000 33814.0 donations
# 22000 36613.0 donations
# 24000 39350.0 donations
# 26000 42199.0 donations
# 28000 44989.0 donations
# 30000 47772.0 donations
# 32000 50536.0 donations
# 34000 53363.0 donations
# 36000 56086.0 donations
# 38000 58911.0 donations
# 40000 61704.0 donations
#
# trial 22 finished with 0.0
#
# 0 793.0 cooperators
# 2000 5504.0 donations
# 4000 9774.0 donations
# 6000 13391.0 donations
# 8000 16649.0 donations
# 10000 19654.0 donations
# 12000 22574.0 donations
# 14000 25419.0 donations
# 16000 28336.0 donations
# 18000 31191.0 donations
# 20000 34075.0 donations
# 22000 36817.0 donations
# 24000 39693.0 donations
# 26000 42599.0 donations
# 28000 45466.0 donations
# 30000 48347.0 donations
# 32000 51279.0 donations
# 34000 54111.0 donations
# 36000 56970.0 donations
# 38000 59816.0 donations
# 40000 62805.0 donations
#
# trial 23 finished with 28.0
#
# 0 834.0 cooperators
# 2000 5787.0 donations
# 4000 10310.0 donations
# 6000 13974.0 donations
# 8000 17097.0 donations
# 10000 20083.0 donations
# 12000 23015.0 donations
# 14000 25889.0 donations
# 16000 28689.0 donations
# 18000 31545.0 donations
# 20000 34334.0 donations
# 22000 37168.0 donations
# 24000 39974.0 donations
# 26000 42776.0 donations
# 28000 45569.0 donations
# 30000 48327.0 donations
# 32000 51138.0 donations
# 34000 53885.0 donations
# 36000 56654.0 donations
# 38000 59517.0 donations
# 40000 62234.0 donations
#
# trial 24 finished with 0.0
#
# 0 789.0 cooperators
# 2000 5548.0 donations
# 4000 9819.0 donations
# 6000 13244.0 donations
# 8000 16416.0 donations
# 10000 19422.0 donations
# 12000 22309.0 donations
# 14000 25156.0 donations
# 16000 27997.0 donations
# 18000 30891.0 donations
# 20000 33700.0 donations
# 22000 36513.0 donations
# 24000 39331.0 donations
# 26000 42220.0 donations
# 28000 45028.0 donations
# 30000 47907.0 donations
# 32000 50703.0 donations
# 34000 53507.0 donations
# 36000 56384.0 donations
# 38000 59245.0 donations
# 40000 62145.0 donations
#
# trial 25 finished with 18.0
#
# 0 805.0 cooperators
# 2000 5544.0 donations
# 4000 9813.0 donations
# 6000 13251.0 donations
# 8000 16459.0 donations
# 10000 19515.0 donations
# 12000 22567.0 donations
# 14000 25530.0 donations
# 16000 28311.0 donations
# 18000 31255.0 donations
# 20000 34158.0 donations
# 22000 37065.0 donations
# 24000 39986.0 donations
# 26000 42871.0 donations
# 28000 45720.0 donations
# 30000 48669.0 donations
# 32000 51612.0 donations
# 34000 54493.0 donations
# 36000 57374.0 donations
# 38000 60250.0 donations
# 40000 63120.0 donations
#
# trial 26 finished with 30.0
#
# 0 812.0 cooperators
# 2000 5612.0 donations
# 4000 9901.0 donations
# 6000 13545.0 donations
# 8000 16732.0 donations
# 10000 19832.0 donations
# 12000 22799.0 donations
# 14000 25701.0 donations
# 16000 28527.0 donations
# 18000 31350.0 donations
# 20000 34226.0 donations
# 22000 36993.0 donations
# 24000 39829.0 donations
# 26000 42633.0 donations
# 28000 45433.0 donations
# 30000 48167.0 donations
# 32000 50939.0 donations
# 34000 53704.0 donations
# 36000 56554.0 donations
# 38000 59282.0 donations
# 40000 62057.0 donations
#
# trial 27 finished with 0.0
#
# 0 796.0 cooperators
# 2000 5611.0 donations
# 4000 9970.0 donations
# 6000 13511.0 donations
# 8000 16712.0 donations
# 10000 19700.0 donations
# 12000 22649.0 donations
# 14000 25476.0 donations
# 16000 28237.0 donations
# 18000 31031.0 donations
# 20000 33842.0 donations
# 22000 36588.0 donations
# 24000 39400.0 donations
# 26000 42156.0 donations
# 28000 44924.0 donations
# 30000 47723.0 donations
# 32000 50499.0 donations
# 34000 53286.0 donations
# 36000 56046.0 donations
# 38000 58778.0 donations
# 40000 61589.0 donations
#
# trial 28 finished with 0.0
#
# 0 812.0 cooperators
# 2000 5645.0 donations
# 4000 9997.0 donations
# 6000 13508.0 donations
# 8000 16638.0 donations
# 10000 19580.0 donations
# 12000 22474.0 donations
# 14000 25294.0 donations
# 16000 28152.0 donations
# 18000 30968.0 donations
# 20000 33765.0 donations
# 22000 36624.0 donations
# 24000 39406.0 donations
# 26000 42178.0 donations
# 28000 44993.0 donations
# 30000 47817.0 donations
# 32000 50535.0 donations
# 34000 53291.0 donations
# 36000 56160.0 donations
# 38000 58915.0 donations
# 40000 61661.0 donations
#
# trial 29 finished with 0.0
#
# 0 779.0 cooperators
# 2000 5545.0 donations
# 4000 9862.0 donations
# 6000 13551.0 donations
# 8000 16613.0 donations
# 10000 19555.0 donations
# 12000 22494.0 donations
# 14000 25291.0 donations
# 16000 28034.0 donations
# 18000 30796.0 donations
# 20000 33512.0 donations
# 22000 36339.0 donations
# 24000 39085.0 donations
# 26000 41775.0 donations
# 28000 44511.0 donations
# 30000 47341.0 donations
# 32000 50225.0 donations
# 34000 53010.0 donations
# 36000 55822.0 donations
# 38000 58637.0 donations
# 40000 61413.0 donations
#
# trial 30 finished with 0.0
#
# 0 772.0 cooperators
# 2000 5595.0 donations
# 4000 9929.0 donations
# 6000 13621.0 donations
# 8000 16919.0 donations
# 10000 19977.0 donations
# 12000 23011.0 donations
# 14000 25896.0 donations
# 16000 28819.0 donations
# 18000 31840.0 donations
# 20000 34805.0 donations
# 22000 37714.0 donations
# 24000 40637.0 donations
# 26000 43606.0 donations
# 28000 46518.0 donations
# 30000 49420.0 donations
# 32000 52275.0 donations
# 34000 55123.0 donations
# 36000 58078.0 donations
# 38000 60982.0 donations
# 40000 63937.0 donations
#
# trial 31 finished with 35.0
#
# 0 798.0 cooperators
# 2000 5670.0 donations
# 4000 10025.0 donations
# 6000 13730.0 donations
# 8000 17059.0 donations
# 10000 20035.0 donations
# 12000 22994.0 donations
# 14000 25926.0 donations
# 16000 28899.0 donations
# 18000 31837.0 donations
# 20000 34834.0 donations
# 22000 37876.0 donations
# 24000 41064.0 donations
# 26000 44087.0 donations
# 28000 47287.0 donations
# 30000 50435.0 donations
# 32000 53647.0 donations
# 34000 56888.0 donations
# 36000 60050.0 donations
# 38000 63265.0 donations
# 40000 66365.0 donations
#
# trial 32 finished with 94.0
#
# 0 780.0 cooperators
# 2000 5450.0 donations
# 4000 9751.0 donations
# 6000 13339.0 donations
# 8000 16624.0 donations
# 10000 19670.0 donations
# 12000 22621.0 donations
# 14000 25447.0 donations
# 16000 28307.0 donations
# 18000 31118.0 donations
# 20000 33898.0 donations
# 22000 36698.0 donations
# 24000 39496.0 donations
# 26000 42304.0 donations
# 28000 45143.0 donations
# 30000 47902.0 donations
# 32000 50701.0 donations
# 34000 53407.0 donations
# 36000 56134.0 donations
# 38000 58919.0 donations
# 40000 61760.0 donations
#
# trial 33 finished with 3.0
#
# 0 795.0 cooperators
# 2000 5594.0 donations
# 4000 9758.0 donations
# 6000 13049.0 donations
# 8000 16107.0 donations
# 10000 19087.0 donations
# 12000 21931.0 donations
# 14000 24737.0 donations
# 16000 27417.0 donations
# 18000 30273.0 donations
# 20000 33058.0 donations
# 22000 35826.0 donations
# 24000 38579.0 donations
# 26000 41339.0 donations
# 28000 44106.0 donations
# 30000 46895.0 donations
# 32000 49665.0 donations
# 34000 52465.0 donations
# 36000 55259.0 donations
# 38000 58031.0 donations
# 40000 60834.0 donations
#
# trial 34 finished with 0.0
#
# 0 778.0 cooperators
# 2000 5555.0 donations
# 4000 9737.0 donations
# 6000 13232.0 donations
# 8000 16360.0 donations
# 10000 19264.0 donations
# 12000 22119.0 donations
# 14000 24900.0 donations
# 16000 27714.0 donations
# 18000 30599.0 donations
# 20000 33420.0 donations
# 22000 36200.0 donations
# 24000 38964.0 donations
# 26000 41676.0 donations
# 28000 44437.0 donations
# 30000 47209.0 donations
# 32000 50076.0 donations
# 34000 52830.0 donations
# 36000 55599.0 donations
# 38000 58424.0 donations
# 40000 61116.0 donations
#
# trial 35 finished with 0.0
#
# 0 806.0 cooperators
# 2000 5709.0 donations
# 4000 10135.0 donations
# 6000 13834.0 donations
# 8000 17146.0 donations
# 10000 20167.0 donations
# 12000 23006.0 donations
# 14000 25885.0 donations
# 16000 28733.0 donations
# 18000 31565.0 donations
# 20000 34358.0 donations
# 22000 37188.0 donations
# 24000 39989.0 donations
# 26000 42773.0 donations
# 28000 45611.0 donations
# 30000 48519.0 donations
# 32000 51329.0 donations
# 34000 54145.0 donations
# 36000 56847.0 donations
# 38000 59656.0 donations
# 40000 62449.0 donations
#
# trial 36 finished with 0.0
#
# 0 821.0 cooperators
# 2000 5660.0 donations
# 4000 10022.0 donations
# 6000 13633.0 donations
# 8000 16913.0 donations
# 10000 19980.0 donations
# 12000 22977.0 donations
# 14000 25869.0 donations
# 16000 28810.0 donations
# 18000 31706.0 donations
# 20000 34552.0 donations
# 22000 37410.0 donations
# 24000 40229.0 donations
# 26000 43069.0 donations
# 28000 45839.0 donations
# 30000 48542.0 donations
# 32000 51314.0 donations
# 34000 54089.0 donations
# 36000 56818.0 donations
# 38000 59545.0 donations
# 40000 62291.0 donations
#
# trial 37 finished with 0.0
#
# 0 782.0 cooperators
# 2000 5568.0 donations
# 4000 9780.0 donations
# 6000 13350.0 donations
# 8000 16427.0 donations
# 10000 19395.0 donations
# 12000 22154.0 donations
# 14000 24922.0 donations
# 16000 27643.0 donations
# 18000 30452.0 donations
# 20000 33221.0 donations
# 22000 36024.0 donations
# 24000 38779.0 donations
# 26000 41546.0 donations
# 28000 44345.0 donations
# 30000 47158.0 donations
# 32000 49962.0 donations
# 34000 52762.0 donations
# 36000 55581.0 donations
# 38000 58373.0 donations
# 40000 61124.0 donations
#
# trial 38 finished with 0.0
#
# 0 802.0 cooperators
# 2000 5704.0 donations
# 4000 10196.0 donations
# 6000 13883.0 donations
# 8000 17280.0 donations
# 10000 20421.0 donations
# 12000 23463.0 donations
# 14000 26522.0 donations
# 16000 29470.0 donations
# 18000 32478.0 donations
# 20000 35385.0 donations
# 22000 38386.0 donations
# 24000 41359.0 donations
# 26000 44368.0 donations
# 28000 47284.0 donations
# 30000 50303.0 donations
# 32000 53322.0 donations
# 34000 56410.0 donations
# 36000 59492.0 donations
# 38000 62641.0 donations
# 40000 65761.0 donations
#
# trial 39 finished with 84.0
#
# 0 816.0 cooperators
# 2000 5730.0 donations
# 4000 10141.0 donations
# 6000 13684.0 donations
# 8000 16921.0 donations
# 10000 20018.0 donations
# 12000 22936.0 donations
# 14000 25824.0 donations
# 16000 28683.0 donations
# 18000 31531.0 donations
# 20000 34314.0 donations
# 22000 37130.0 donations
# 24000 39881.0 donations
# 26000 42647.0 donations
# 28000 45450.0 donations
# 30000 48172.0 donations
# 32000 50916.0 donations
# 34000 53680.0 donations
# 36000 56387.0 donations
# 38000 59198.0 donations
# 40000 61933.0 donations
#
# trial 40 finished with 0.0
#
# 0 791.0 cooperators
# 2000 5576.0 donations
# 4000 9825.0 donations
# 6000 13349.0 donations
# 8000 16417.0 donations
# 10000 19369.0 donations
# 12000 22228.0 donations
# 14000 25083.0 donations
# 16000 27837.0 donations
# 18000 30577.0 donations
# 20000 33384.0 donations
# 22000 36076.0 donations
# 24000 38871.0 donations
# 26000 41597.0 donations
# 28000 44350.0 donations
# 30000 47152.0 donations
# 32000 49891.0 donations
# 34000 52663.0 donations
# 36000 55493.0 donations
# 38000 58335.0 donations
# 40000 61091.0 donations
#
# trial 41 finished with 0.0
#
# 0 820.0 cooperators
# 2000 5641.0 donations
# 4000 9943.0 donations
# 6000 13495.0 donations
# 8000 16723.0 donations
# 10000 19836.0 donations
# 12000 22892.0 donations
# 14000 25818.0 donations
# 16000 28733.0 donations
# 18000 31626.0 donations
# 20000 34479.0 donations
# 22000 37219.0 donations
# 24000 40033.0 donations
# 26000 42819.0 donations
# 28000 45684.0 donations
# 30000 48438.0 donations
# 32000 51231.0 donations
# 34000 54020.0 donations
# 36000 56811.0 donations
# 38000 59530.0 donations
# 40000 62233.0 donations
#
# trial 42 finished with 0.0
#
# 0 835.0 cooperators
# 2000 5869.0 donations
# 4000 10369.0 donations
# 6000 14144.0 donations
# 8000 17454.0 donations
# 10000 20524.0 donations
# 12000 23485.0 donations
# 14000 26470.0 donations
# 16000 29321.0 donations
# 18000 32303.0 donations
# 20000 35225.0 donations
# 22000 38107.0 donations
# 24000 41075.0 donations
# 26000 44074.0 donations
# 28000 46976.0 donations
# 30000 49903.0 donations
# 32000 52914.0 donations
# 34000 55771.0 donations
# 36000 58799.0 donations
# 38000 61837.0 donations
# 40000 64825.0 donations
#
# trial 43 finished with 51.0
#
# 0 796.0 cooperators
# 2000 5627.0 donations
# 4000 9991.0 donations
# 6000 13548.0 donations
# 8000 16691.0 donations
# 10000 19666.0 donations
# 12000 22543.0 donations
# 14000 25417.0 donations
# 16000 28203.0 donations
# 18000 31037.0 donations
# 20000 33826.0 donations
# 22000 36613.0 donations
# 24000 39355.0 donations
# 26000 42102.0 donations
# 28000 44871.0 donations
# 30000 47647.0 donations
# 32000 50362.0 donations
# 34000 53241.0 donations
# 36000 56008.0 donations
# 38000 58775.0 donations
# 40000 61560.0 donations
#
# trial 44 finished with 0.0
#
# 0 801.0 cooperators
# 2000 5618.0 donations
# 4000 9807.0 donations
# 6000 13244.0 donations
# 8000 16418.0 donations
# 10000 19463.0 donations
# 12000 22447.0 donations
# 14000 25337.0 donations
# 16000 28153.0 donations
# 18000 31006.0 donations
# 20000 33846.0 donations
# 22000 36729.0 donations
# 24000 39541.0 donations
# 26000 42435.0 donations
# 28000 45321.0 donations
# 30000 48196.0 donations
# 32000 51137.0 donations
# 34000 53977.0 donations
# 36000 56905.0 donations
# 38000 59772.0 donations
# 40000 62677.0 donations
#
# trial 45 finished with 25.0
#
# 0 739.0 cooperators
# 2000 5393.0 donations
# 4000 9453.0 donations
# 6000 12903.0 donations
# 8000 16059.0 donations
# 10000 19012.0 donations
# 12000 21905.0 donations
# 14000 24670.0 donations
# 16000 27490.0 donations
# 18000 30290.0 donations
# 20000 33049.0 donations
# 22000 35809.0 donations
# 24000 38593.0 donations
# 26000 41278.0 donations
# 28000 44118.0 donations
# 30000 46960.0 donations
# 32000 49738.0 donations
# 34000 52470.0 donations
# 36000 55185.0 donations
# 38000 57932.0 donations
# 40000 60711.0 donations
#
# trial 46 finished with 0.0
# 0 770.0 cooperators
# 2000 5539.0 donations
# 4000 9872.0 donations
# 6000 13434.0 donations
# 8000 16644.0 donations
# 10000 19795.0 donations
# 12000 22781.0 donations
# 14000 25739.0 donations
# 16000 28667.0 donations
# 18000 31544.0 donations
# 20000 34444.0 donations
# 22000 37252.0 donations
# 24000 40044.0 donations
# 26000 42914.0 donations
# 28000 45780.0 donations
# 30000 48652.0 donations
# 32000 51336.0 donations
# 34000 54198.0 donations
# 36000 57023.0 donations
# 38000 59806.0 donations
# 40000 62502.0 donations
#
# trial 47 finished with 3.0
#
# 0 773.0 cooperators
# 2000 5629.0 donations
# 4000 9890.0 donations
# 6000 13497.0 donations
# 8000 16650.0 donations
# 10000 19729.0 donations
# 12000 22800.0 donations
# 14000 25720.0 donations
# 16000 28538.0 donations
# 18000 31408.0 donations
# 20000 34241.0 donations
# 22000 37062.0 donations
# 24000 39887.0 donations
# 26000 42818.0 donations
# 28000 45738.0 donations
# 30000 48592.0 donations
# 32000 51430.0 donations
# 34000 54299.0 donations
# 36000 57188.0 donations
# 38000 60192.0 donations
# 40000 63109.0 donations
#
# trial 48 finished with 45.0
#
# 0 807.0 cooperators
# 2000 5681.0 donations
# 4000 10041.0 donations
# 6000 13649.0 donations
# 8000 16850.0 donations
# 10000 19896.0 donations
# 12000 22915.0 donations
# 14000 25895.0 donations
# 16000 28773.0 donations
# 18000 31628.0 donations
# 20000 34495.0 donations
# 22000 37398.0 donations
# 24000 40183.0 donations
# 26000 43019.0 donations
# 28000 45780.0 donations
# 30000 48623.0 donations
# 32000 51472.0 donations
# 34000 54330.0 donations
# 36000 57290.0 donations
# 38000 60140.0 donations
# 40000 62996.0 donations
#
# trial 49 finished with 24.0
#
# 0 801.0 cooperators
# 2000 5719.0 donations
# 4000 10028.0 donations
# 6000 13569.0 donations
# 8000 16890.0 donations
# 10000 19933.0 donations
# 12000 22831.0 donations
# 14000 25648.0 donations
# 16000 28491.0 donations
# 18000 31197.0 donations
# 20000 34015.0 donations
# 22000 36857.0 donations
# 24000 39624.0 donations
# 26000 42327.0 donations
# 28000 45170.0 donations
# 30000 47962.0 donations
# 32000 50795.0 donations
# 34000 53589.0 donations
# 36000 56416.0 donations
# 38000 59188.0 donations
# 40000 61951.0 donations
#
# trial 50 finished with 0.0
#
# 0 763.0 cooperators
# 2000 5348.0 donations
# 4000 9561.0 donations
# 6000 13039.0 donations
# 8000 16131.0 donations
# 10000 19070.0 donations
# 12000 21986.0 donations
# 14000 24917.0 donations
# 16000 27718.0 donations
# 18000 30576.0 donations
# 20000 33439.0 donations
# 22000 36213.0 donations
# 24000 39005.0 donations
# 26000 41866.0 donations
# 28000 44615.0 donations
# 30000 47383.0 donations
# 32000 50195.0 donations
# 34000 53102.0 donations
# 36000 55910.0 donations
# 38000 58670.0 donations
# 40000 61372.0 donations
#
# trial 51 finished with 0.0
#
# 0 776.0 cooperators
# 2000 5483.0 donations
# 4000 9789.0 donations
# 6000 13147.0 donations
# 8000 16275.0 donations
# 10000 19267.0 donations
# 12000 22211.0 donations
# 14000 25074.0 donations
# 16000 27990.0 donations
# 18000 30875.0 donations
# 20000 33762.0 donations
# 22000 36650.0 donations
# 24000 39582.0 donations
# 26000 42481.0 donations
# 28000 45313.0 donations
# 30000 48174.0 donations
# 32000 51005.0 donations
# 34000 53870.0 donations
# 36000 56651.0 donations
# 38000 59571.0 donations
# 40000 62390.0 donations
#
# trial 52 finished with 6.0
#
# 0 808.0 cooperators
# 2000 5573.0 donations
# 4000 9830.0 donations
# 6000 13448.0 donations
# 8000 16553.0 donations
# 10000 19487.0 donations
# 12000 22359.0 donations
# 14000 25338.0 donations
# 16000 28121.0 donations
# 18000 31032.0 donations
# 20000 33913.0 donations
# 22000 36742.0 donations
# 24000 39597.0 donations
# 26000 42433.0 donations
# 28000 45279.0 donations
# 30000 48112.0 donations
# 32000 50968.0 donations
# 34000 53904.0 donations
# 36000 56865.0 donations
# 38000 59864.0 donations
# 40000 62785.0 donations
#
# trial 53 finished with 47.0
#
# 0 806.0 cooperators
# 2000 5635.0 donations
# 4000 9971.0 donations
# 6000 13454.0 donations
# 8000 16730.0 donations
# 10000 19825.0 donations
# 12000 22818.0 donations
# 14000 25850.0 donations
# 16000 28740.0 donations
# 18000 31677.0 donations
# 20000 34526.0 donations
# 22000 37490.0 donations
# 24000 40492.0 donations
# 26000 43480.0 donations
# 28000 46497.0 donations
# 30000 49508.0 donations
# 32000 52570.0 donations
# 34000 55657.0 donations
# 36000 58805.0 donations
# 38000 62018.0 donations
# 40000 65217.0 donations
#
# trial 54 finished with 86.0
#
# 0 778.0 cooperators
# 2000 5543.0 donations
# 4000 9620.0 donations
# 6000 13116.0 donations
# 8000 16264.0 donations
# 10000 19192.0 donations
# 12000 22017.0 donations
# 14000 24725.0 donations
# 16000 27493.0 donations
# 18000 30278.0 donations
# 20000 33035.0 donations
# 22000 35876.0 donations
# 24000 38696.0 donations
# 26000 41457.0 donations
# 28000 44221.0 donations
# 30000 46991.0 donations
# 32000 49741.0 donations
# 34000 52578.0 donations
# 36000 55427.0 donations
# 38000 58177.0 donations
# 40000 60905.0 donations
#
# trial 55 finished with 0.0
#
# 0 804.0 cooperators
# 2000 5632.0 donations
# 4000 9904.0 donations
# 6000 13541.0 donations
# 8000 16716.0 donations
# 10000 19671.0 donations
# 12000 22592.0 donations
# 14000 25505.0 donations
# 16000 28345.0 donations
# 18000 31232.0 donations
# 20000 34086.0 donations
# 22000 36937.0 donations
# 24000 39843.0 donations
# 26000 42764.0 donations
# 28000 45541.0 donations
# 30000 48445.0 donations
# 32000 51322.0 donations
# 34000 54202.0 donations
# 36000 57143.0 donations
# 38000 60022.0 donations
# 40000 63113.0 donations
#
# trial 56 finished with 54.0
#
# 0 800.0 cooperators
# 2000 5730.0 donations
# 4000 9890.0 donations
# 6000 13374.0 donations
# 8000 16520.0 donations
# 10000 19577.0 donations
# 12000 22496.0 donations
# 14000 25389.0 donations
# 16000 28160.0 donations
# 18000 31019.0 donations
# 20000 33826.0 donations
# 22000 36688.0 donations
# 24000 39508.0 donations
# 26000 42348.0 donations
# 28000 45268.0 donations
# 30000 48191.0 donations
# 32000 50964.0 donations
# 34000 53901.0 donations
# 36000 56700.0 donations
# 38000 59538.0 donations
# 40000 62386.0 donations
#
# trial 57 finished with 22.0
#
# 0 782.0 cooperators
# 2000 5425.0 donations
# 4000 9600.0 donations
# 6000 13080.0 donations
# 8000 16162.0 donations
# 10000 19082.0 donations
# 12000 22042.0 donations
# 14000 24885.0 donations
# 16000 27730.0 donations
# 18000 30519.0 donations
# 20000 33296.0 donations
# 22000 36044.0 donations
# 24000 38846.0 donations
# 26000 41617.0 donations
# 28000 44414.0 donations
# 30000 47185.0 donations
# 32000 49950.0 donations
# 34000 52626.0 donations
# 36000 55447.0 donations
# 38000 58229.0 donations
# 40000 61022.0 donations
#
# trial 58 finished with 0.0
#
# 0 813.0 cooperators
# 2000 5660.0 donations
# 4000 10008.0 donations
# 6000 13525.0 donations
# 8000 16742.0 donations
# 10000 19746.0 donations
# 12000 22682.0 donations
# 14000 25636.0 donations
# 16000 28431.0 donations
# 18000 31315.0 donations
# 20000 34061.0 donations
# 22000 36912.0 donations
# 24000 39687.0 donations
# 26000 42490.0 donations
# 28000 45310.0 donations
# 30000 48008.0 donations
# 32000 50808.0 donations
# 34000 53577.0 donations
# 36000 56400.0 donations
# 38000 59240.0 donations
# 40000 61976.0 donations
#
# trial 59 finished with 0.0
#
# 0 820.0 cooperators
# 2000 5764.0 donations
# 4000 10321.0 donations
# 6000 14049.0 donations
# 8000 17435.0 donations
# 10000 20648.0 donations
# 12000 23675.0 donations
# 14000 26782.0 donations
# 16000 29771.0 donations
# 18000 32764.0 donations
# 20000 35837.0 donations
# 22000 38866.0 donations
# 24000 41896.0 donations
# 26000 44920.0 donations
# 28000 47945.0 donations
# 30000 50982.0 donations
# 32000 54037.0 donations
# 34000 57137.0 donations
# 36000 60135.0 donations
# 38000 63237.0 donations
# 40000 66422.0 donations
#
# trial 60 finished with 83.0
#
# 0 819.0 cooperators
# 2000 5720.0 donations
# 4000 10132.0 donations
# 6000 13833.0 donations
# 8000 17125.0 donations
# 10000 20184.0 donations
# 12000 23210.0 donations
# 14000 26186.0 donations
# 16000 29065.0 donations
# 18000 31973.0 donations
# 20000 34859.0 donations
# 22000 37886.0 donations
# 24000 40743.0 donations
# 26000 43740.0 donations
# 28000 46627.0 donations
# 30000 49690.0 donations
# 32000 52662.0 donations
# 34000 55592.0 donations
# 36000 58631.0 donations
# 38000 61731.0 donations
# 40000 64690.0 donations
#
# trial 61 finished with 62.0
#
# 0 789.0 cooperators
# 2000 5604.0 donations
# 4000 9983.0 donations
# 6000 13678.0 donations
# 8000 16828.0 donations
# 10000 19897.0 donations
# 12000 22800.0 donations
# 14000 25681.0 donations
# 16000 28586.0 donations
# 18000 31417.0 donations
# 20000 34268.0 donations
# 22000 37093.0 donations
# 24000 40051.0 donations
# 26000 42987.0 donations
# 28000 45892.0 donations
# 30000 48753.0 donations
# 32000 51655.0 donations
# 34000 54617.0 donations
# 36000 57636.0 donations
# 38000 60559.0 donations
# 40000 63522.0 donations
#
# trial 62 finished with 35.0
#
# 8.887104448212517 hours

# %%
#PARAMETERS FOR SPATIAL RANGE
N = 40 #for use in the NxN lattice, total population size = N^2
n = np.power(N,2) #population size
p = 10 #each player starts with £p
benefit_IR = 15 #benefit received by recipient #will have to manually change this
cost_IR = 1.25 #cost to donor
donation_PG = 1.25 #amount a cooperator pays
r = 2 #cooperators give donation_PG then the total amount is multiplied by r 
#where 1 < r < n = N^2 and divided by everyone
IR_range = 8
no_rounds = 40000
no_trials = 30
spatial = True

import time
start_time = time.time()

defectors_time = []
cooperators_time = []
av_cooperators = np.zeros(int(no_rounds/100+1))
final_don = []
final_cd = []
final_dc = []


for trial in range(no_trials):
    #the three main properties that any individual has
    reputation = [[] for i in range(no_rounds+1)]  
    strategy = [[] for i in range(no_rounds+1)] 
    payoff = [[] for i in range(no_rounds+1)] 

    #metrics used for evalutation
    no_cooperators = np.zeros(no_rounds+1) 
    av_defector_payoff = np.zeros(no_rounds+1) 
    av_cooperator_payoff = np.zeros(no_rounds+1) 
    cum_donations = np.zeros(no_rounds+1)  
    cum_cd_swaps = np.zeros(no_rounds+1)  
    cum_dc_swaps = np.zeros(no_rounds+1) 
    cum_rep_known = np.zeros(no_rounds+1)

    #initial values
    reputation[0] = np.ones([N,N]) #everyone starts with a reputation of 1
    strategy[0] = np.random.randint(2, size=(N, N), ) #uniformly random distributed strategies
    payoff[0] = np.array([[p for i in range(N)] for j in range(N)], dtype=float) #everyone starts with the same amount of money
    no_cooperators[0] = np.sum(strategy[0])
    av_defector_payoff[0] = p
    av_cooperator_payoff[0] = p

    print(0, no_cooperators[0],"cooperators")
    
    
    #repeat round for every time step
    for t in range(1,no_rounds+1):
        #copy across all properties for new time step
        reputation[t] = reputation[t-1].copy()
        strategy[t] = strategy[t-1].copy()
        payoff[t] = payoff[t-1].copy()
        no_cooperators[t] = no_cooperators[t-1].copy()
        cum_cd_swaps[t] = cum_cd_swaps[t-1]
        cum_dc_swaps[t] = cum_dc_swaps[t-1]
        cum_donations[t] = cum_donations[t-1]
        cum_rep_known[t] = cum_rep_known[t-1]
            
        if t % 2000 ==0:
            print(t, no_cooperators[t],"cooperators")

        #public goods 5x with the focus of each game being a member of x's 1-vn-nhd
        x = np.random.randint(N,size=[2])
        for focus in vn_nhd(x, 1):
            public_goods(vn_nhd(focus,1),t)

        #indirect reciprocity 5x with the recipient of each game being a member of x's 1-vn-nhd
        for focus in vn_nhd(x, 1):
            if spatial == True:
                indirect_reciprocity_spatial(random_neighbour(focus,IR_range), focus, t) 
                #focus = recipient, random player in lattice = donor
            else:
                indirect_reciprocity(random_neighbour(focus,IR_range), focus, t)

        #x decides whether to emulate neighbour's strategy or not
        update_rule(x,random_neighbour(x,1),t)
            
    
    for i in range(0, no_rounds + 100,100):
        av_cooperators[int(i/100)] += no_cooperators[i]/no_trials
    
    extinct = np.where(no_cooperators==0)[0]
    if extinct.size > 1:
        defectors_time.append(extinct[0])
        
    extinct = np.where(no_cooperators==n)[0]
    if extinct.size > 1:
        cooperators_time.append(extinct[0])
    print(cooperators_time)
        
    final_don.append(cum_donations[no_rounds])
    final_cd.append(cum_cd_swaps[no_rounds])
    final_dc.append(cum_dc_swaps[no_rounds])
    


        
    print("\ntrial", trial, "finished with", no_cooperators[no_rounds],"\n")

print(cooperators_time)
with open('Spatial_range_dom.csv', 'a') as f:
    writer_ob = writer(f)
    writer_ob.writerow([benefit_IR, defectors_time, cooperators_time])
    f.close()
    
with open('Spatial_range_cooperators.csv', 'a') as f:
    writer_ob = writer(f)
    writer_ob.writerow([benefit_IR, av_cooperators])
    f.close()
    
with open('Spatial_range_don.csv', 'a') as f:
    writer_ob = writer(f)
    writer_ob.writerow([benefit_IR, np.mean(final_don)])
    f.close()
        
with open('Spatial_range_swaps.csv', 'a') as f:
    writer_ob = writer(f)
    writer_ob.writerow([benefit_IR, np.mean(final_dc), np.mean(final_cd)])
    f.close()

print((time.time() - start_time)/3600, "hours")

# %% [markdown]
# ## Creating Lattice Visualisations for Single Runs

# %%
#GENERATING PIXEL

N = 40 #for use in the NxN lattice, total population size = N^2
n = np.power(N,2) #population size
p = 10 #each player starts with £p
benefit_IR = 0 #benefit received by recipient
cost_IR = 0 #cost to donor
donation_PG = 1.25 #amount a cooperator pays
r = 2 #cooperators give donation_PG then the total amount is multiplied by r where 1 < r < n = N^2 and divided by everyone
IR_range = 1
no_rounds = 40000
spatial = False

import time
start_time = time.time()


#the three main properties that any individual has
reputation = [[] for i in range(no_rounds+1)]  
strategy = [[] for i in range(no_rounds+1)] 
payoff = [[] for i in range(no_rounds+1)] 


#initial values
reputation[0] = np.ones([N,N]) #everyone starts with a reputation of 1
strategy[0] = np.random.randint(2, size=(N, N), ) 
#uniformly random distributed strategies
payoff[0] = np.array([[p for i in range(N)] for j in range(N)], dtype=float) 
#everyone starts with the same amount of money

no_cooperators = np.zeros(no_rounds+1) 
no_cooperators[0] = np.sum(strategy[0])



print(0, no_cooperators[0],"cooperators")


#repeat round for every time step
for t in range(1,no_rounds+1):
    #copy across all properties for new time step
    reputation[t] = reputation[t-1].copy()
    strategy[t] = strategy[t-1].copy()
    payoff[t] = payoff[t-1].copy()
    no_cooperators[t] = no_cooperators[t-1].copy()


    if t % 2000 ==0:
        print(t, no_cooperators[t],"cooperators")

    #public goods 5x with the focus of each game being a member of x's 1-vn-nhd
    x = np.random.randint(N,size=[2])
    for focus in vn_nhd(x, 1):
        public_goods(vn_nhd(focus,1),t)

    #indirect reciprocity 5x with the recipient of each game being a member of x's 1-vn-nhd
    for focus in vn_nhd(x, 1):
        if spatial == True:
            indirect_reciprocity_spatial(random_neighbour(focus,IR_range), focus, t) 
            #focus = recipient, random player in lattice = donor
        else:
            indirect_reciprocity(random_neighbour(focus,IR_range), focus, t)

    #x decides whether to emulate neighbour's strategy or not
    update_rule(x,random_neighbour(x,1),t)


print("\ntrial", trial, "finished with", no_cooperators[no_rounds],"\n")

print((time.time() - start_time)/3600, "hours")

# %%
folder = "PGPixel"

#create line graph to show number of cooperators
x = np.linspace(0,40000,40001)
plt.plot(x, no_cooperators, color="#094A25")
plt.ylabel("Number of Cooperators")
plt.xlabel("Time step (thousands)")
plt.title("Cooperators over Time")
plt.savefig(fname = folder + "/timeseries.jpg")
plt.show()

plt.plot(x,[29 for i in range(40001)], color = "red", linestyle = "--")
plt.plot(x,[8 for i in range(40001)], color = "red", linestyle = "--")
plt.plot(x, no_cooperators, color="#094A25")
plt.ylim(0,20)
plt.xlim(0,40000)
plt.yticks(range(5,35,5))
plt.ylabel("Number of Cooperators")
plt.xlabel("Time step (thousands)")
plt.title("Cooperators over Time")
plt.savefig(fname = folder + "/timeseries_zoom.jpg")
plt.show()


extinct = np.where(no_cooperators==0)[0]
print(extinct[0])

#plot each player as pixel
for plot_t in range(0,40001,5000):
    plt.imshow(strategy[plot_t], cmap = cmap, vmin = 0, vmax = 1)
    plt.title(f"t = {plot_t}")
    plt.xticks([10*i for i in range(round(N/10))])
    plt.yticks([10*i for i in range(round(N/10))])
    #plt.xlim(10,20)
    #plt.ylim(30,40)
    plt.xticks([], [])
    plt.yticks([], [])
    plt.savefig(fname = folder + "/" + str(plot_t) + ".jpg")
    plt.show()
